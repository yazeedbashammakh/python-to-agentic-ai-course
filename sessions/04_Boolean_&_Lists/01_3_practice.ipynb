# %% [markdown]
# # Practice Notebook: Variables, Numbers, Strings & Booleans
#
# This notebook contains mixed practice problems covering everything learned so far.
#
# Topics covered:
#
# - Numbers
# - Variables
# - Strings
# - String Methods
# - String Indexing & Slicing
# - Type Checking
# - Reassignment
# - Booleans
# - None
#
# Try solving each problem before moving to the next one.
#
# Do not use Google or AI assistance until you have attempted the problem yourself.

# %% [markdown]
# # Problem 1
#
# Create a variable called `age` and assign your age to it.
#
# Display:
#
# ```text
# My age is: <age>
# ```
# using an f-string.

# %%
# Write your code here

# %% [markdown]
# # Problem 2
#
# Create two variables:
#
# ```python
# length = 15
# width = 8
# ```
#
# Calculate the area of a rectangle.

# %%
# Write your code here

# %% [markdown]
# # Problem 3
#
# A bank account starts with:
#
# ```python
# balance = 5000
# ```
#
# Perform the following:
#
# 1. Deposit 2000
# 2. Withdraw 1500
# 3. Deposit 750
#
# Display the final balance.

# %%
# Write your code here

# %% [markdown]
# # Problem 4
#
# Predict the output before running:
#
# ```python
# x = 10
# x += 5
# x *= 2
# x -= 8
#
# print(x)
# ```

# %%
# Run after prediction

# %% [markdown]
# # Problem 5
#
# Convert:
#
# ```python
# salary = 45000
# ```
#
# into:
#
# ```python
# salary_after_bonus
# ```
#
# where bonus = 15%.

# %%
# Write your code here

# %% [markdown]
# # Problem 6
#
# Create a variable:
#
# ```python
# name = "Python"
# ```
#
# Print the first character.

# %%
# Write your code here

# %% [markdown]
# # Problem 7
#
# Using the same string:
#
# ```python
# name = "Python"
# ```
#
# Print the last character.

# %%
# Write your code here

# %% [markdown]
# # Problem 8
#
# Extract the word:
#
# ```text
# Engineer
# ```
#
# from:
#
# ```python
# text = "AI Engineer"
# ```

# %%
# Write your code here

# %% [markdown]
# # Problem 9
#
# Without typing the word again, create:
#
# ```text
# PythonPythonPythonPython
# ```
#
# using string repetition.

# %%
# Write your code here

# %% [markdown]
# # Problem 10
#
# Convert:
#
# ```python
# text = "machine learning"
# ```
#
# into uppercase.

# %%
# Write your code here

# %% [markdown]
# # Problem 11
#
# Convert:
#
# ```python
# text = "artificial intelligence"
# ```
#
# into title case.

# %%
# Write your code here

# %% [markdown]
# # Problem 12
#
# Replace:
#
# ```python
# "I love Java"
# ```
#
# with:
#
# ```python
# "I love Python"
# ```

# %%
# Write your code here

# %% [markdown]
# # Problem 13
#
# Create:
#
# ```python
# first_name
# last_name
# ```
#
# Output:
#
# ```text
# Last Name, First Name
# ```

# %%
# Write your code here

# %% [markdown]
# # Problem 14
#
# Create:
#
# ```python
# city = "Mumbai"
# country = "India"
# ```
#
# Display:
#
# ```text
# I live in Mumbai, India.
# ```

# %%
# Write your code here

# %% [markdown]
# # Problem 15
#
# Store your favorite programming language in a variable.
#
# Display:
#
# ```text
# My favorite language is <language>.
# ```

# %%
# Write your code here

# %% [markdown]
# # Problem 16
#
# For each of the following values:
#
# ```python
# 100
# 12.75
# "AI Engineer"
# True
# None
# ```
#
# 1. Predict the data type before running the code.
# 2. Verify your answers using the `type()` function.
#
# Can you identify which values belong to:
#
# - int
# - float
# - str
# - bool
# - NoneType

# %%
# Write your code here

# %% [markdown]
# # Problem 17
#
# A student receives the following marks:
#
# ```python
# math = 85
# science = 92
# english = 78
# ```
#
# Calculate:
#
# 1. Total marks
# 2. Average marks
#
# Display the result using an f-string:
#
# ```text
# Total Marks: ___
# Average Marks: ___
# ```

# %%
# Write your code here

# %% [markdown]
# # Problem 18
#
# Create a variable:
#
# ```python
# full_name = "John Doe"
# ```
#
# Using string indexing and slicing only:
#
# Extract:
#
# ```text
# John
# Doe
# ```
#
# Store them in separate variables and display them.

# %%
# Write your code here

# %% [markdown]
# # Problem 19
#
# Store:
#
# ```python
# is_student = True
# ```
#
# Display the value and its type.

# %%
# Write your code here

# %% [markdown]
# # Problem 20
#
# Predict the output without running the code.
#
# ```python
# x = 10
#
# x += 5
# x *= 2
# x -= 8
#
# print(x)
# ```
#
# After predicting, run the code and verify your answer.
#
# Explain each step of the calculation.

# %%
# Write your prediction here

# Run the code below

# %% [markdown]
# # Problem 21
#
# Given:
#
# ```python
# name = "Artificial Intelligence"
# ```
#
# Without counting characters manually:
#
# Print:
#
# 1. First character
# 2. Last character
# 3. First word
# 4. Second word
# 5. Length of the string

# %%
# Write your code here

# %% [markdown]
# # Problem 22
#
# A product costs:
#
# ```python
# price = 2500
# ```
#
# A customer receives:
#
# - 10% discount
# - 18% GST on the discounted price
#
# Calculate:
#
# 1. Discount amount
# 2. Price after discount
# 3. GST amount
# 4. Final payable amount
#
# Display all values clearly.

# %%
# Write your code here

# %% [markdown]
# # Problem 23
#
# Create:
#
# ```python
# first_name = "John"
# last_name = "Doe"
# ```
#
# Display the following using string formatting:
#
# ```text
# Doe, John
# ```
#
# Do not manually type:
#
# ```text
# Doe, John
# ```
#
# Use the variables only.

# %%
# Write your code here

# %% [markdown]
# # Problem 24
#
# Predict the output.
#
# ```python
# word = "Python"
#
# print(word[-1])
# print(word[-3])
# print(word[:4])
# print(word[2:])
# ```
#
# Explain why each output is produced.

# %%
# Write your prediction here

# %% [markdown]
# # Problem 25
#
# Create:
#
# ```python
# username = "student_2025"
# ```
#
# Create a Boolean variable:
#
# ```python
# is_long_username
# ```
#
# that stores whether the username contains more than 10 characters.
#
# Display:
#
# - username
# - length
# - Boolean result

# %%
# Write your code here

# %% [markdown]
# # Problem 26
#
# Given:
#
# ```python
# sentence = "Python For AI Engineers"
# ```
#
# Extract:
#
# ```text
# Python
# AI
# Engineers
# ```
#
# Store each word in a separate variable.
#
# Use slicing only.

# %%
# Write your code here

# %% [markdown]
# # Problem 27
#
# Debug the following code:
#
# ```python
# name = "Rohan"
#
# print("Hello " + 25)
# ```
#
# Questions:
#
# 1. Why does this code fail?
# 2. Fix the code.

# %%
# Write your solution here

# %% [markdown]
# # Problem 28
#
# Create:
#
# ```python
# salary = 75000
# bonus_percentage = 12
# ```
#
# Calculate:
#
# - Bonus amount
# - Final salary
#
# Display the results using an f-string.

# %%
# Write your code here

# %% [markdown]
# # Problem 29
#
# Predict the final value of:
#
# ```python
# x = 5
#
# x *= 4
# x += 10
# x /= 2
# x -= 3
#
# print(x)
# ```
#
# Show every intermediate step.

# %%
# Write your prediction here

# %% [markdown]
# # Problem 30
#
# Create:
#
# ```python
# course = "Python to Agentic AI Engineering"
# ```
#
# Without typing any word manually:
#
# Display:
#
# ```text
# Python
# Agentic
# Engineering
# ```
#
# Use slicing only.

# %%
# Write your code here

# %% [markdown]
# # Problem 31
#
# Create:
#
# ```python
# email = None
# ```
#
# Display:
#
# 1. Value of email
# 2. Data type of email
#
# Then update:
#
# ```python
# email = "student@gmail.com"
# ```
#
# Display the new value and data type.

# %%
# Write your code here

# %% [markdown]
# # Problem 32
#
# Predict the output.
#
# ```python
# text = "Machine Learning"
#
# print(text[:7])
# print(text[8:])
# print(text[-8:])
# ```
#
# Explain your reasoning.

# %%
# Write your prediction here

# %% [markdown]
# # Problem 33
#
# Create:
#
# ```python
# temperature = 38
# ```
#
# Store the result of:
#
# ```python
# temperature > 35
# ```
#
# in a variable called:
#
# ```python
# is_hot
# ```
#
# Display:
#
# - temperature
# - is_hot
# - data type of is_hot

# %%
# Write your code here

# %% [markdown]
# # Problem 34
#
# A student receives marks:
#
# ```python
# python = 82
# sql = 74
# ai = 91
# ```
#
# Calculate:
#
# 1. Total marks
# 2. Average marks
#
# Store each result in a variable and display them.

# %%
# Write your code here

# %% [markdown]
# # Problem 35 - Final Challenge
#
# Create:
#
# ```python
# name = "John Doe"
# salary = 50000
# bonus_rate = 0.10
# ```
#
# Calculate:
#
# 1. Bonus amount
# 2. Final salary
#
# Display the result exactly as:
#
# ```text
# Employee: John Doe
# Bonus: 5000.0
# Final Salary: 55000.0
# ```
#
# Requirements:
#
# - Use variables
# - Use arithmetic operators
# - Use an f-string
# - Store intermediate results in separate variables

# %%
# Write your code here
