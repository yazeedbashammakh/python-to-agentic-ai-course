# %% [markdown]
# # Practice Questions
#
# Try solving these questions without referring back to the examples.
#
# If you get stuck, revisit the relevant section and try again.
#
# Remember, the goal is not just to write code but to understand **why** you're writing it.

# %% [markdown]
# ## Problem 1: Create a list containing five programming languages.
#
# Print:
#
# - Entire list
# - First language
# - Last language

# %%
# Write your code here

# %% [markdown]
# ## Problem 2: Create a list of five cities.
#
# Replace the third city with another city of your choice.

# %%
# Write your code here

# %% [markdown]
# ## Problem 3: Create a list:
#
# ```python
# marks = [85, 92, 78, 88, 95]
# ```
#
# Calculate:
#
# - Total marks
# - Number of subjects

# %%
# Write your code here

# %% [markdown]
# ## Problem 4: Using:
#
# ```python
# students = ["Rohan", "Mohan", "Chandu", "Ajay", "Vijay"]
# ```
#
# Print:
#
# - First student
# - Last student
# - Middle student

# %%
# Write your code here

# %% [markdown]
# ## Problem 5: Add three new students to the list using `append()`.

# %%
# Write your code here

# %% [markdown]
# ## Problem 6: Insert a student at index position 2.

# %%
# Write your code here

# %% [markdown]
# ## Problem 7: Remove the last two students from the list and store them in variables.

# %%
# Write your code here

# %% [markdown]
# ## Problem 8: Check whether:
#
# ```python
# "Ajay"
# ```
#
# exists in the list.
#
# Store the result in a Boolean variable.

# %%
# Write your code here

# %% [markdown]
# ## Proble 9: Create a list of five numbers.
#
# Print:
#
# - Largest number
# - Smallest number

# %%
# Write your code here

# %% [markdown]
# ## Problem 10: Reverse the following list:
#
# ```python
# languages = ["Python", "Java", "C++", "JavaScript"]
# ```

# %%
# Write your code here

# %% [markdown]
# ## Problem 11: Sort the following list alphabetically:
#
# ```python
# students = ["Vijay", "Ajay", "Mohan", "Rohan", "Chandu"]
# ```

# %%
# Write your code here

# %% [markdown]
# ## Problem 12: Create a shopping cart list.
#
# Add:
#
# - Laptop
# - Mouse
# - Keyboard
#
# Then remove one item.

# %%
# Write your code here

# %% [markdown]
# ## Problem 13: Create a list containing:
#
# ```python
# ["Python", "Python", "SQL", "Python", "AI"]
# ```
#
# Count how many times `"Python"` appears.

# %%
# Write your code here

# %% [markdown]
# ## Problem 14: Using slicing only:
#
# ```python
# students = ["Rohan", "Mohan", "Chandu", "Ajay", "Vijay"]
# ```
#
# Extract:
#
# - First three students
# - Last three students

# %%
# Write your code here

# %% [markdown]
# ## Problem 15: Create a list containing 10 numbers.
#
# Print:
#
# - First 5 numbers
# - Last 5 numbers
# - Total number of elements

# %%
# Write your code here

# %% [markdown]
# # Mini Challenge: Student Management System
#
# Create a list of students:
#
# ```python
# students = [
#     "Rohan",
#     "Mohan",
#     "Chandu",
#     "Ajay",
#     "Vijay"
# ]
# ```
#
# Perform the following operations:
#
# 1. Add two new students.
# 2. Remove one student.
# 3. Insert a student at index 2.
# 4. Check whether `"Ajay"` exists.
# 5. Count total students.
# 6. Sort the list.
# 7. Reverse the list.
# 8. Display the final list.
#
# Try completing the challenge without looking back at previous examples.

# %%
# Write your solution here
