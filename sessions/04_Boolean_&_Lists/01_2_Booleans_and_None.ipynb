# %% [markdown]
# # Practice Questions
#
# Try solving these questions without referring back to the examples.
#
# If you get stuck, revisit the relevant section and try again.
#
# Remember, the goal is not just to write code but to understand **why** you're writing it.

# %% [markdown]
# # Problem 1: Creating Booleans
#
# Create two variables:
#
# - `is_student`
# - `has_completed_course`
#
# Assign Boolean values to them.

# %%
# Write your code here

# %% [markdown]
# # Problem 2: Predict the Output
#
# Without running the code, predict the result.

# %%
10 > 15

# %% [markdown]
# Will the result be `True` or `False`?

# %% [markdown]
# # Problem 3: Comparison Operations
#
# Evaluate the following expressions.

# %%
5 > 2

# %%
3 == 10

# %%
8 != 8

# %% [markdown]
# # Problem 4: Store Boolean Results
#
# Store the result of each comparison in a variable.

# %%
# Example:
# result = 10 > 5

# %%
# Write your code here

# %% [markdown]
# # Problem 5: Working with None
#
# Create a variable called:
#
# ```python
# phone_number
# ```
#
# Assign it a value of `None`.
#
# Then update it with your phone number (or a sample number).

# %%
# Write your code here

# %% [markdown]
# # Mini Challenge Exercise
#
# A course website stores whether a student has passed an exam.
#
# Create:
#
# ```python
# exam_passed = True
# ```
#
# Then create another variable:
#
# ```python
# certificate_generated = False
# ```
#
# Display both variables and check their data types.

# %%
# Write your code here
