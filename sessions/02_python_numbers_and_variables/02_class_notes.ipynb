# %% [markdown]
# **Notebook File:**
# .ipynb --> Interactive Python Notebook --> rapid development, testing,
# it combines code + documentation.
#
# **python File:**
# .py --> Python file.
#
#
#
# **Most important things to watch out for in python**.
#
# "  --> Where it starts.
# " --> Where it ends.
# ' -->
# ' -->.
# """     --> Triple Quotes starts
# """     --> Triple Quotes ends.
# '''
#
# (       )   --> Brackets
# ,           --> Comma.
#
#
#
# print("Hi World")
#
# print --> function ka naam.
# ( --> inputs are given inside brackets
# ) --> input ends here
# ""  --> input inside bracket

# %%
print("Hi World")
print("Hi My name is Yazeed")

print('Hi My name is Yazeed')

print("""
We are reading and writing.
We are playing.
We are learning python basics.
This is first class for python.
""")
# Out:
# Hi World
# Hi My name is Yazeed
# Hi My name is Yazeed
#
# We are reading and writing.
# We are playing.
# We are learning python basics.
# This is first class for python.

# %%
print("Hi My name is Yazeed'")
# Out:
# Hi My name is Yazeed'

# %%
print('Abraham Lincoln said "Learn Python"')

# %%
print("It's raining today.")

# %%
# bracket not closed then failed
print("It's raining today."

# %%
# end quote missed then failed
print("It's raining today.)

# %%
# Print numbers
print(123)
# Out:
# 123

# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
3/2
# Out:
# 1.5

# %%
2*2
# Out:
# 4

# %%
# Remainder/Modulo
7%4
# Out:
# 3

# %%
# Power
2**4
# Out:
# 16

# %%
16**0.5
# Out:
# 4.0

# %%
2 + 3 -5*6/2*3
# Out:
# -40.0

# %%
(2+10)/3*(5-3)
# Out:
# 8.0

# %% [markdown]
# Variables:
#
# Maths:
# y = 2x + 3
#
# x,y --> variables --> It can varies
#
# let x = 1.
#
# y = 2(1) + 3
# y = 5
#
# let x = 6
# y = 2(6) + 3 = 15

# %%
x = 1
y = 2*x+3
print(y)
# Out:
# 5

# %%
x = 5
y = 2*x+3
print(y)
# Out:
# 13

# %%
# Print 3 five times (Without variable)
print(3)
print(3)
print(3)
print(3)
print(3)
print(3)

# %%
# Print ant number five times (With variable)
x = 10

print(x)
print(x)
print(x)
print(x)
print(x)
print(x)
# Out:
# 10
# 10
# 10
# 10
# 10
# 10

# %%
# Variables can be updated
x = 1
print(x)
x = 2
print(x)
# Out:
# 1
# 2

# %%
maths = 75

# Recheck --> 3 marks remove hoge

maths = maths - 3

print(maths)

# = --> assignment operator
# Out:
# 72

# %%
maths -= 3
maths
# Out:
# 69

# %%
maths += 3
maths
# Out:
# 72

# %%
maths *= 3
maths
# Out:
# 216

# %%
maths /= 3
maths
# Out:
# 72.0

# %%
income = 100
tax_rate = 0.1
tax = income * tax_rate

# %%
print(tax)
# Out:
# 10.0

# %%
x = 1
y = 2*x+2
z = y + 2*x +5
print(z)
# Out:
# 11

# %%
# DRY coding --> Donot Repeat Yourself
