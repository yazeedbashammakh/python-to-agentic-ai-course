# %% [markdown]
# # Practice 1: Create Variables
#
# Create three variables:
#
# - `name`
# - `age`
# - `city`
#
# Store your own information and display each variable.

# %%
# Write your code here

# %% [markdown]
# # Practice 2: Predict the Output
#
# Without running the code, predict the value of `x`.

# %%
# Write your code here

# %% [markdown]
# # Practice 3: Bank Balance
#
# Create a variable called `balance`.
#
# 1. Start with 1000
# 2. Add 500
# 3. Subtract 200
# 4. Display the final balance

# %%
# Write your code here

# %% [markdown]
# # Practice 4: Shopping Cart
#
# A customer buys:
#
# - Item 1 = 250
# - Item 2 = 400
# - Item 3 = 150
#
# Store each value in a variable and calculate the total bill.

# %%
# Write your code here

# %% [markdown]
# # Practice 5: Temperature Conversion
#
# The formula is:
#
# ```python
# fahrenheit = (celsius * 9/5) + 32
# ```
#
# Create a variable called `celsius` and convert it to Fahrenheit.

# %%
# Write your code here

# %% [markdown]
# A company gives employees a 10% bonus.
#
# Create:
#
# ```python
# salary = 50000
# ```
#
# Calculate:
#
# 1. Bonus amount
# 2. Final salary after bonus
#
# Store each value in a separate variable.

# %%
# Write your code here
