# %% [markdown]
# # 📝 Practice Exercises
#
# Now it's your turn.
#
# Try to solve these questions without looking at the previous examples.
#
# Remember:
#
# - Files help us save data permanently.
# - JSON helps us store structured data.
# - Python can read and write files.
# - JSON is commonly used to save application data.
#
# Let's start with simple exercises and gradually build a Student Database.

# %% [markdown]
# ## Q1. Create a File
#
# Create a file named:
#
# notes.txt
#
# Write the following text into it:
#
# Hello Python
#
# Then open the file and verify its contents.

# %%
# Write your code here

# %% [markdown]
# ## Q2. Read a File
#
# Read the contents of:
#
# notes.txt
#
# and display it on the screen.

# %%
# Write your code here

# %% [markdown]
# ## Q3. Append Data
#
# Add the following line to notes.txt:
#
# Welcome to Files
#
# Then read the file again and display the updated content.

# %%
# Write your code here

# %% [markdown]
# ## Q4. Dictionary to JSON
#
# Create a dictionary containing:
#
# - name
# - age
#
# Convert it into a JSON string using:
#
# dumps()
#
# Display the result.

# %%
# Write your code here

# %% [markdown]
# ## Q5. JSON to Dictionary
#
# Convert the following JSON string into a Python dictionary:
#
# {"name":"Rohan","marks":85}
#
# Display the dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Q6. Save Student Data
#
# Create a dictionary:
#
# {
#     "name": "Rohan",
#     "marks": 85
# }
#
# Save it into:
#
# student.json

# %%
# Write your code here

# %% [markdown]
# ## Q7. Read Student Data
#
# Read student.json and display its contents.

# %%
# Write your code here

# %% [markdown]
# ## Q8. Save Multiple Students
#
# Create a list containing three students.
#
# Example:
#
# [
#     {"name":"Rohan","marks":85},
#     {"name":"Mohan","marks":90},
#     {"name":"Ajay","marks":75}
# ]
#
# Save the list into:
#
# students.json

# %%
# Write your code here

# %% [markdown]
# ## Q9. Load Multiple Students
#
# Read students.json.
#
# Display all student records.

# %%
# Write your code here

# %% [markdown]
# ## Q10. Student Report
#
# Read students.json.
#
# Display output like:
#
# Name  : Rohan
# Marks : 85
#
# --------------------
#
# Name  : Mohan
# Marks : 90
#
# --------------------

# %%
# Write your code here

# %% [markdown]
# ## Q11. Theory Questions
#
# Answer the following:
#
# 1. What is a file?
# 2. What is JSON?
# 3. Difference between dump() and dumps()?
# 4. Difference between load() and loads()?
# 5. What is pip?
# 6. What is YAML used for?

# %%
Write your answers below:

# %% [markdown]
# # Mini Project
#
# Create a Student Database.
#
# Requirements:
#
# 1. Create a list of 5 students.
# 2. Save them into students.json.
# 3. Read the file.
# 4. Display all student details.

# %%
# Write your code here

# %% [markdown]
# # Assignment: School Student Database
#
# Create a JSON file named:
#
# school_database.json
#
# Store at least 5 students.
#
# Each student must contain:
#
# - Name
# - Roll Number
# - Marks
#
# Tasks:
#
# 1. Save data into the JSON file.
# 2. Read data from the JSON file.
# 3. Display all student records neatly.
#
# Expected Output:
#
# Name  : Rohan
# Roll  : 101
# Marks : 85
#
# ---------------------
#
# Name  : Mohan
# Roll  : 102
# Marks : 90
#
# ---------------------
