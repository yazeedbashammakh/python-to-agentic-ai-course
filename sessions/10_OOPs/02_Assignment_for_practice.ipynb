# %% [markdown]
# # 📝 Practice Exercises
#
# Now it's your turn.
#
# Try to solve the following questions without looking at previous code.
#
# Remember:
#
# - A Class is a blueprint.
# - An Object is an instance of a class.
# - A Constructor initializes data automatically.
# - Methods perform actions related to an object.
#
# Start with simple questions and gradually move to more challenging ones.
#
# ---

# %% [markdown]
# ## Q1. Create a Car Class
#
# Create a class named `Car`.
#
# Then create two objects:
#
# - car1
# - car2
#
# Print their types using `type()`.

# %%
# Write your code here

# %% [markdown]
# ## Q2. Create a Mobile Class
#
# Create a class named `Mobile`.
#
# Create three objects:
#
# - mobile1
# - mobile2
# - mobile3
#
# Print all three objects.

# %%
# Write your code here

# %% [markdown]
# ## Q3. Adding Data to Objects
#
# Create a class named `Book`.
#
# Create an object named `book1`.
#
# Add:
#
# - title = "Python Programming"
# - price = 500
#
# Print both values.

# %%
# Write your code here

# %% [markdown]
# ## Q4. Using a Constructor
#
# Create a class named `Book`.
#
# The constructor should accept:
#
# - title
# - price
#
# Create two book objects and display their details.

# %%
# Write your code here

# %% [markdown]
# ## Q5. Employee Records
#
# Create an Employee class.
#
# Store:
#
# - name
# - employee_id
# - salary
#
# Create three Employee objects and print their details.

# %%
# Write your code here

# %% [markdown]
# ## Q6. Student Display Method
#
# Create a Student class.
#
# Store:
#
# - name
# - roll
# - marks
#
# Create a method named `display()`.
#
# Create two student objects and display their details.

# %%
# Write your code here

# %% [markdown]
# ## Q7. Pass or Fail
#
# Add a method named `is_pass()`.
#
# Rules:
#
# - Marks >= 35 → Pass
# - Otherwise → Fail
#
# Create three students and test the method.

# %%
# Write your code here

# %% [markdown]
# ## Q8. Update Marks
#
# Add a method named `update_marks()`.
#
# The method should accept new marks and update the student's marks.
#
# Display the student details before and after updating.

# %%
# Write your code here

# %% [markdown]
# ## Q9. Store Objects in a List
#
# Create three Student objects.
#
# Store them inside a list.
#
# Use a loop to display all student details.

# %%
# Write your code here

# %% [markdown]
# ## Q10. Grade Calculator
#
# Add a method named `calculate_grade()`.
#
# Rules:
#
# | Marks | Grade |
# |---------|---------|
# | 90+ | A |
# | 75-89 | B |
# | 50-74 | C |
# | Below 50 | D |
#
# Create four students and display:
#
# - Name
# - Marks
# - Grade

# %%
# Write your code here

# %% [markdown]
# # Assignment: Student Management System
#
# Create a Student class.
#
# The class should store:
#
# - name
# - roll
# - marks
#
# Create the following methods:
#
# 1. display()
# 2. is_pass()
# 3. update_marks()
# 4. calculate_grade()
#
# Create at least 5 students.
#
# Store them inside a list.
#
# Using a loop:
#
# - Display all students
# - Check pass/fail
# - Display grades
#
# Expected Output Example:
#
# Name  : Rohan
# Roll  : 101
# Marks : 85
# Pass  : True
# Grade : B
#
# ------------------------
