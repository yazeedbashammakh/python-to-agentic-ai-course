# %% [markdown]
# # Practice Questions
#
# Try solving these questions without referring back to the examples.
#
# If you get stuck, revisit the relevant section and try again.
#
# Remember, the goal is not just to write code but to understand **why** you're writing it.

# %% [markdown]
# ## Problem 1
#
# Predict the output before running the code.
#
# ```python
# fruits = [
#     "Apple",
#     "Mango",
#     "Banana"
# ]
#
# for fruit in fruits:
#     print(fruit)
# ```
#
# Explain why the output is produced.

# %% [markdown]
# Write your answer here before running the code.
#
# ```__________________________________________________```

# %% [markdown]
# ## Problem 2
#
# Predict the output before running the code.
#
# ```python
# numbers = [2, 4, 6]
#
# total = 0
#
# for number in numbers:
#     total += number
#
# print(total)
# ```
#
# Explain how the value of `total` changes during each iteration.

# %% [markdown]
# Write your answer here before running the code.
#
# ```__________________________________________________```

# %% [markdown]
# ## Problem 3
#
# Predict the output before running the code.
#
# ```python
# marks = [78, 35, 90]
#
# for mark in marks:
#
#     if mark >= 40:
#         print("Pass")
#     else:
#         print("Fail")
# ```
#
# Explain how the loop and conditional statement work together.

# %% [markdown]
# Write your answer here before running the code.
#
# ```__________________________________________________```

# %% [markdown]
# ## Problem 4
#
# Predict the output before running the code.
#
# ```python
# for number in range(2, 8, 2):
#     print(number)
# ```
#
# Explain why only those numbers are printed.

# %% [markdown]
# Write your answer here before running the code.
#
# ```__________________________________________________```

# %% [markdown]
# ## Problem 5
#
# Predict the output before running the code.
#
# ```python
# students = {
#     "Rohan": 78,
#     "Ajay": 65
# }
#
# for student, marks in students.items():
#     print(student, "-", marks)
# ```
#
# Explain what `student` and `marks` represent during each iteration.

# %% [markdown]
# Write your answer here before running the code.
#
# ```__________________________________________________```

# %% [markdown]
# ## Problem 6
#
# You are given the following list.
#
# ```python
# students = [
#     "Rohan",
#     "Ajay",
#     "Mohan",
#     "Vijay",
#     "Chandu"
# ]
# ```
#
# Using a `for` loop, print every student's name.

# %%
# Write your code here

# %% [markdown]
# ## Problem 7
#
# Given the following marks.
#
# ```python
# marks = [75, 82, 68, 91, 55]
# ```
#
# Using a loop:
#
# - Calculate the total marks.
# - Calculate the average marks.
# - Print both values.
#
# Do not manually type any mark.

# %%
# Write your code here

# %% [markdown]
# ## Problem 8
#
# Given the following marks.
#
# ```python
# marks = [78, 35, 91, 29, 67, 40]
# ```
#
# Using a loop:
#
# - Print `"Pass"` for marks greater than or equal to `40`.
# - Print `"Fail"` otherwise.
#
# Display both the mark and the result.

# %%
# Write your code here

# %% [markdown]
# ## Problem 9
#
# Given the following list.
#
# ```python
# marks = [78, 35, 91, 29, 67]
# ```
#
# Create a new list containing only the students who passed.
#
# A student passes if the marks are greater than or equal to `40`.
#
# Print the new list.

# %%
# Write your code here

# %% [markdown]
# ## Problem 10
#
# Using `range()`:
#
# - Print the numbers from `10` to `20`.
# - Print only the even numbers.
#
# Do not create a list manually.

# %%
# Write your code here

# %% [markdown]
# ## Problem 11
#
# You are given the following dictionary.
#
# ```python
# students = {
#     "Rohan": 78,
#     "Ajay": 35,
#     "Mohan": 91,
#     "Vijay": 67,
#     "Chandu": 28
# }
# ```
#
# Using a loop:
#
# - Print the student's name and marks.
# - Print `"Pass"` if the marks are greater than or equal to `40`.
# - Otherwise print `"Fail"`.
#
# Expected Output (Example)
#
# ```
# Rohan - 78 - Pass
# Ajay - 35 - Fail
# ...
# ```

# %%
# Write your code here

# %% [markdown]
# ## Problem 12
#
# Given the following dictionary.
#
# ```python
# products = {
#     "Laptop": 65000,
#     "Mouse": 1200,
#     "Keyboard": 2500,
#     "Monitor": 18000
# }
# ```
#
# Using a loop:
#
# - Print only the products whose price is greater than ₹5000.

# %%
# Write your code here

# %% [markdown]
# ## Problem 13
#
# You are given the following list.
#
# ```python
# marks = [75, 82, 91, 68, 55]
# ```
#
# Create a new list that stores grades instead of marks.
#
# Rules:
#
# - 90 or above → Grade A
# - 75–89 → Grade B
# - 60–74 → Grade C
# - Below 60 → Grade D
#
# Print the final list.

# %%
# Write your code here

# %% [markdown]
# ## Problem 14
#
# A store keeps product information like this.
#
# ```python
# products = {
#     "Laptop": {
#         "price": 65000,
#         "stock": 5
#     },
#     "Mouse": {
#         "price": 1200,
#         "stock": 20
#     },
#     "Keyboard": {
#         "price": 2500,
#         "stock": 10
#     }
# }
# ```
#
# Using a loop:
#
# Calculate the inventory value of every product.
#
# Formula:
#
# ```
# Inventory Value = Price × Stock
# ```
#
# Store the result inside the dictionary as a new key called `"inventory_value"`.
#
# Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Problem 15
#
# You are given the following nested dictionary.
#
# ```python
# products = {
#     "Laptop": {
#         "price": 65000,
#         "stock": 5
#     },
#     "Mouse": {
#         "price": 1200,
#         "stock": 20
#     },
#     "Keyboard": {
#         "price": 2500,
#         "stock": 10
#     },
#     "Monitor": {
#         "price": 18000,
#         "stock": 4
#     }
# }
# ```
#
# Using loops:
#
# 1. Calculate the inventory value of every product.
# 2. Store it as `"inventory_value"`.
# 3. Print only the products whose inventory value is greater than ₹50,000.
#
# Do not manually calculate any inventory value.

# %%
# Write your code here

# %% [markdown]
# # Mini Challenge : School Report Management System
#
# A school stores students' marks using the following dictionary.
#
# ```python
# students = {
#     "Rohan": {
#         "maths": 78,
#         "science": 85,
#         "english": 90
#     },
#     "Ajay": {
#         "maths": 35,
#         "science": 42,
#         "english": 50
#     },
#     "Mohan": {
#         "maths": 91,
#         "science": 88,
#         "english": 95
#     },
#     "Vijay": {
#         "maths": 60,
#         "science": 58,
#         "english": 72
#     }
# }
# ```
#
# Perform the following tasks.
#
# 1. Calculate the total marks of every student.
# 2. Calculate the average marks of every student.
# 3. Store both `"total"` and `"average"` inside each student's dictionary.
# 4. Display every student's report.
# 5. Print only the students whose average marks are **70 or above**.
# 6. Print the name of the student with the highest total marks.
#
# Use everything you've learned so far:
#
# - Lists
# - Dictionaries
# - Comparison Operators
# - Logical Operators
# - Conditional Statements
# - For Loops
