# %% [markdown]
# # Practice Questions
#
# Try solving these questions without referring back to the examples.
#
# If you get stuck, revisit the relevant section and try again.
#
# Remember, the goal is not just to write code but to understand **why** you're writing it.

# %% [markdown]
# ## Problem 1
#
# Predict the output before running the code.

# %%
count = 1

while count <= 5:
    print(count)
    count += 2

# %% [markdown]
# ## Problem 2
#
# Predict the output before running the code.

# %%
students = ["Rohan", "Mohan", "Ajay"]

index = 0

while index < len(students):
    print(students[index])
    index += 1

print("Finished")

# %% [markdown]
# ## Problem 3
#
# Predict the output before running the code.

# %%
count = 5

while count > 0:
    print(count)

    if count == 3:
        break

    count -= 1

# %% [markdown]
# ## Problem 4
#
# Predict the output before running the code.

# %%
numbers = [10, 20, 30, 40]

index = 0

while index < len(numbers):

    number = numbers[index]
    index += 1

    if number == 20:
        continue

    print(number)

# %% [markdown]
# ## Problem 5
#
# Predict the output before running the code.

# %%
count = 1

while count <= 3:
    print(count)
    count += 1

else:
    print("Loop Finished")

# %% [markdown]
# Now it's time to apply what you've learned.
#
# We'll continue using the same student database, with each question building on the previous one. This is similar to how requirements evolve in real-world software projects.
#
# Try solving each problem on your own before looking at the solution. Focus on the logic as much as the code.

# %%
student_marks = {
    "Rohan": {
        "Maths": 83,
        "English": 75,
        "Science": 89
    },
    "Mohan": {
        "Maths": 89,
        "English": 91,
        "Science": 93
    },
    "Chandu": {
        "Maths": 65,
        "English": 78,
        "Science": 74
    },
    "Ajay": {
        "Maths": 46,
        "English": 52,
        "Science": 48
    },
    "Vijay": {
        "Maths": 70,
        "English": 80,
        "Science": 98
    }
}

# %% [markdown]
# ## Problem 6
#
# The school wants to know the total marks obtained by every student.
#
# Using a **while** loop:
#
# - Calculate the total marks for every student.
# - Print the student's name along with their total.
#
# Do not manually type any marks.

# %%
# Write your code here

# %% [markdown]
# ## Problem 7
#
# The principal now wants to know each student's percentage.
#
# Using the same dictionary:
#
# - Calculate the percentage of every student.
# - Print the student's name and percentage rounded to two decimal places.
#
# Do not manually type any marks.

# %%
# Write your code here

# %% [markdown]
# ## Problem 8
#
# The report card now requires grades.
#
# Using the same dictionary:
#
# - Calculate the percentage.
# - Assign grades using the following rules.
#
# ```
# 90 and above  → Grade A
# 75 and above  → Grade B
# 60 and above  → Grade C
# Otherwise      → Grade D
# ```
#
# Print the report in the following format:
#
# ```
# Student - Percentage - Grade
# ```

# %%
# Write your code here

# %% [markdown]
# ## Problem 9
#
# The school wants all report card information stored permanently.
#
# Instead of only printing the results:
#
# - Calculate the total.
# - Calculate the percentage.
# - Determine the grade.
#
# Store all three values inside each student's dictionary using the keys:
#
# - `"Total"`
# - `"Percentage"`
# - `"Grade"`
#
# Finally, print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Problem 10
#
# The school has introduced a passing rule.
#
# A student passes only if **every subject** has marks greater than or equal to **50**.
#
# Using the updated dictionary:
#
# - Determine whether each student has **Passed** or **Failed**.
# - Store the result inside the dictionary using the key `"Result"`.
#
# Finally, print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Problem 11
#
# The principal wants to quickly find **Ajay's** report.
#
# Using a **while** loop:
#
# - Search for `"Ajay"`.
# - As soon as the student is found:
#     - Print the complete report.
#     - Stop searching immediately.
#
# Use the `break` statement.

# %%
# Write your code here

# %% [markdown]
# ## Problem 12
#
# The report should only display students who passed.
#
# Using a **while** loop:
#
# - Skip every student whose `"Result"` is `"Fail"`.
# - Display the remaining student reports.
#
# Use the `continue` statement.

# %%
# Write your code here

# %% [markdown]
# ## Problem 13
#
# The school wants class statistics.
#
# Using the updated dictionary, calculate:
#
# - Total Students
# - Passed Students
# - Failed Students
# - Highest Percentage
#
# Do not manually type any student's name.

# %%
# Write your code here

# %% [markdown]
# ## Problem 14
#
# The school now wants a list of the top-performing students.
#
# Using a **while** loop:
#
# - Find every student whose percentage is **80 or above**.
# - Store their names inside a new list called `top_students`.
# - Print the final list.

# %%
# Write your code here

# %% [markdown]
# ## Problem 15
#
# The school wants a complete class summary.
#
# Using the updated dictionary, display the following report:
#
# ```
# ========== CLASS SUMMARY ==========
# Total Students :
# Passed Students :
# Failed Students :
# Average Class Percentage :
# Highest Percentage :
# Top Students :
# ===================================
# ```
#
# You may create additional variables or lists if needed.
#
# Try to solve this problem without creating another dictionary.

# %%
# Write your code here

# %% [markdown]
# # Mini Challenge: Student Report Card Generator
#
# You've learned how to use:
#
# - Dictionaries
# - Conditional Statements
# - Comparison & Logical Operators
# - While Loops
#
# Now it's time to combine everything you've learned into a small real-world application.
#
# Imagine a school has asked you to automatically generate report cards for every student.

# %% [markdown]
# ## Client Requirements
#
# Using the `student_marks` dictionary, write a program that performs all of the following tasks.
#
# ### For Every Student
#
# 1. Calculate the total marks.
# 2. Calculate the percentage.
# 3. Assign a grade using the following rules.
#
# ```
# 90 and above  → Grade A
# 75 and above  → Grade B
# 60 and above  → Grade C
# Otherwise      → Grade D
# ```
#
# 4. Determine the result.
#
# ```
# A student passes only if every subject has marks greater than or equal to 50.
# ```
#
# 5. Store the following information back into the student's dictionary.
#
# ```
# Total
# Percentage
# Grade
# Result
# ```
#
# 6. Display the complete report for every student.

# %%
student_marks = {
    "Rohan": {
        "Maths": 83,
        "English": 75,
        "Science": 89
    },
    "Mohan": {
        "Maths": 89,
        "English": 91,
        "Science": 93
    },
    "Chandu": {
        "Maths": 65,
        "English": 78,
        "Science": 74
    },
    "Ajay": {
        "Maths": 46,
        "English": 52,
        "Science": 48
    },
    "Vijay": {
        "Maths": 70,
        "English": 80,
        "Science": 98
    }
}

# Write your solution here
