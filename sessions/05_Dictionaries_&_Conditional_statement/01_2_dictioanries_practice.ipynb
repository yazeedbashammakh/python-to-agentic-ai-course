# %% [markdown]
# # Practice Questions
#
# Try solving these questions without referring back to the examples.
#
# If you get stuck, revisit the relevant section and try again.
#
# Remember, the goal is not just to write code but to understand **why** you're writing it.

# %% [markdown]
# ## Problem 1
#
# Create a dictionary to store the following information about yourself:
#
# - Name
# - Age
# - City
#
# Print the complete dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Problem 2
#
# Using the dictionary created in Problem 1:
#
# - Print only your name.
# - Print only your city.

# %%
# Write your code here

# %% [markdown]
# ## Problem 3
#
# Create a dictionary for a laptop containing:
#
# - Brand
# - RAM
# - Storage
#
# Add a new key called `"price"` and assign a value to it.

# %%
# Write your code here

# %% [markdown]
# ## Problem 4
#
# Using the laptop dictionary from Problem 3:
#
# Remove the `"price"` key and display the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Problem 5
#
# Create a dictionary containing details of your favorite mobile phone.
#
# Include at least five keys.
#
# Print the value of each key separately.

# %%
# Write your code here

# %% [markdown]
# ## Problem 6
#
# You are building a report card for a student.
#
# ```python
# marks = {
#     "maths": 78,
#     "science": 91,
#     "english": 84
# }
# ```
#
# Without manually typing any number:
#
# 1. Calculate the total marks.
# 2. Calculate the average marks.
# 3. Increase every subject by 5 marks.
# 4. Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Problem 7
#
# Predict the output before running the code.
#
# ```python
# student = {
#     "name": "Rohan",
#     "age": 20
# }
#
# student["age"] += 2
# student["city"] = "Pune"
# del student["name"]
#
# print(student)
# ```
#
# Explain each operation.

# %%
# write your answer here before runnig it

# %% [markdown]
# ## Problem 8
#
# Given:
#
# ```python
# employee = {
#     "name": "John",
#     "salary": 60000,
#     "experience": 4
# }
# ```
#
# Update the dictionary so that:
#
# - Salary increases by 15%.
# - Add a new key called `"bonus"` whose value is 20% of the updated salary.
# - Print only the values.

# %%
# Write your solution below

# %% [markdown]
# ## Problem 9
#
# Create a dictionary for three products.
#
# Each product should contain:
#
# - Price
# - Quantity
#
# Example:
#
# ```python
# {
#     "Laptop": {
#         ...
#     }
# }
# ```
#
# Now calculate the inventory value of every product.
#
# Formula:
#
# ```
# Inventory Value = Price × Quantity
# ```
#
# Store the result inside the dictionary as a new key called `"inventory_value"`.

# %%
# Write your solution below

# %% [markdown]
# ## Problem 10
#
# A library stores books like this:
#
# ```python
# library = {
#     "Python": 12,
#     "SQL": 7,
#     "Machine Learning": 5
# }
# ```
#
# Perform the following:
#
# - Add a new book.
# - Increase Python copies by 5.
# - Remove SQL.
# - Print the total number of books available.

# %%
# Write your solution below

# %% [markdown]
# ## Problem 11
#
# Predict the output.
#
# ```python
# marks = {
#     "maths": 80,
#     "science": 70,
#     "english": 90
# }
#
# marks["science"] += marks["maths"]
#
# print(marks)
# ```
#
# Explain why the output is produced.

# %%
# Write your solution below

# %% [markdown]
# ## Problem 12
#
# Given:
#
# ```python
# students = {
#     "Rohan": {
#         "maths": 60,
#         "science": 70,
#         "english": 80
#     },
#     "Ajay": {
#         "maths": 75,
#         "science": 90,
#         "english": 65
#     }
# }
# ```
#
# Without manually typing any marks:
#
# Calculate the total marks of:
#
# - Rohan
# - Ajay
#
# Store both totals in separate variables.

# %%
# Write your solution below

# %% [markdown]
# ## Problem 13
#
# Create a student database.
#
# Each student should have:
#
# - Name
# - Marks
# - City
#
# Add a new student.
#
# Update one student's city.
#
# Remove another student.
#
# Finally display:
#
# - All student names
# - Total number of students

# %%
# Write your solution below

# %% [markdown]
# ## Problem 14
#
# You receive the following dictionary.
#
# ```python
# student = {
#     "name": "Rohan",
#     "marks": [80, 70, 90]
# }
# ```
#
# Without changing the list:
#
# Calculate:
#
# - Total marks
# - Average marks
#
# Store both as new keys inside the dictionary.
#
# The final dictionary should look similar to:
#
# ```python
# {
#     ...
#     "total": ...
#     "average": ...
# }
# ```

# %%
# Write your solution below

# %% [markdown]
# ## Problem 15
#
# Suppose you are building a small e-commerce application.
#
# Create a dictionary for three products.
#
# Each product should store:
#
# - Price
# - Stock
#
# Now perform ALL of the following:
#
# 1. Increase the stock of one product.
# 2. Reduce the stock of another product.
# 3. Add a new product.
# 4. Remove one product.
# 5. Calculate the inventory value (Price × Stock) for every remaining product.
# 6. Print the complete updated dictionary.

# %%
# Write your solution below

# %% [markdown]
# # Mini Challenge: Inventory Management System
#
# You are developing an inventory management system for an electronics store.
#
# Create the following dictionary.
#
# ```python
# inventory = {
#     "Laptop": {
#         "price": 65000,
#         "stock": 8
#     },
#     "Mouse": {
#         "price": 1200,
#         "stock": 25
#     },
#     "Keyboard": {
#         "price": 2500,
#         "stock": 15
#     }
# }
# ```
#
# Perform the following tasks.
#
# 1. Increase the Laptop stock by 5.
# 2. Reduce the Mouse stock by 10.
# 3. Add a new product called Monitor.
# 4. Remove the Keyboard.
# 5. Calculate the inventory value for every product.
#
# Formula:
#
# ```
# Inventory Value = Price × Stock
# ```
#
# 6. Store the inventory value as a new key.
# 7. Display all product names.
# 8. Display the final inventory.

# %%
# Write your solution below
