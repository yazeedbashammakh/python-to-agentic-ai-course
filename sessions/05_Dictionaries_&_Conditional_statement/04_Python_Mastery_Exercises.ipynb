# %% [markdown]
# # 01 Student Management System
#
# In this section, you'll gradually build a simple Student Management System.
#
# Each question builds on the previous one, so try to reuse and improve your existing solution instead of creating everything from scratch.
#
# By the end of this section, you'll have built your first small Python application.

# %% [markdown]
# ## Question 1
#
# Create a dictionary to store the following details of a student.
#
# - Name
# - Age
# - City
# - Marks in Maths
# - Marks in Science
# - Marks in English
#
# Print the complete dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 2
#
# Using the dictionary created in Question 1:
#
# 1. Calculate the total marks.
# 2. Calculate the average marks.
# 3. Store both values inside the dictionary using new keys:
#
# - `"total"`
# - `"average"`
#
# Finally, print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 3
#
# Using the same dictionary,
#
# assign a grade based on the student's average marks.
#
# Rules:
#
# - Below 40 → Failed
# - 40–59 → Grade D
# - 60–69 → Grade C
# - 70–79 → Grade B
# - 80–89 → Grade A
# - 90 and above → Grade A+
#
# Store the grade inside the dictionary using the key `"grade"`.
#
# Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 4
#
# A student receives a scholarship only if:
#
# - Maths marks are greater than 80.
# - Science marks are greater than 80.
#
# Determine whether the student is eligible.
#
# Store the result inside the dictionary using the key:
#
# ```python
# "scholarship"
# ```
#
# Possible values:
#
# - `"Eligible"`
# - `"Not Eligible"`
#
# Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 5
#
# Create a list called `available_cities`.
#
# Add at least five city names.
#
# Check whether the student's city exists in this list.
#
# If it does,
#
# store
#
# ```python
# "Hostel Available"
# ```
#
# otherwise store
#
# ```python
# "Hostel Not Available"
# ```
#
# using the key
#
# ```python
# "hostel"
# ```
#
# Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 6
#
# The school has introduced a sports program.
#
# Create another dictionary called `sports`.
#
# Store whether the student participates in the following sports.
#
# - Cricket
# - Football
# - Basketball
#
# Choose suitable values yourself.
#
# Add this dictionary to the student's dictionary using the key:
#
# ```python
# "sports"
# ```
#
# Print the complete student dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 7
#
# The school is selecting students for an Academic Excellence Award.
#
# A student qualifies only if:
#
# - The grade is either `"Grade A"` or `"Grade A+"`.
# - The student is eligible for a scholarship.
#
# Determine whether the student qualifies.
#
# Store the result using the key:
#
# ```python
# "award"
# ```
#
# Possible values:
#
# - `"Selected"`
# - `"Not Selected"`
#
# Print the updated dictionary.

# %%
# Write your code here.

# %% [markdown]
# ## Question 8
#
# The school wants to maintain emergency contact information.
#
# Add a new dictionary called `"guardian"` inside the student dictionary.
#
# Include:
#
# - Guardian Name
# - Phone Number
# - Relationship
#
# Print the updated student dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 9
#
# The school is organizing an inter-school competition.
#
# A student can participate only if:
#
# - The student's name exists in the following list.
#
# ```python
# participants = [
#     "Rohan",
#     "Ajay",
#     "Mohan",
#     "Vijay"
# ]
# ```
#
# - AND the student has been selected for the Academic Excellence Award.
#
# Store the result inside the dictionary using the key:
#
# ```python
# "competition"
# ```
#
# Possible values:
#
# - `"Eligible"`
# - `"Not Eligible"`
#
# Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 10
#
# Your Student Management System is now complete.
#
# Display the following information in a readable format.
#
# - Student Name
# - City
# - Total Marks
# - Average Marks
# - Grade
# - Scholarship Status
# - Hostel Status
# - Award Status
# - Competition Eligibility
#
# Use the values stored in your dictionary instead of manually typing them.

# %%
# Write your code here

# %% [markdown]
# # 02 Library Management System
#
# In this section, you'll continue improving your Python problem-solving skills by building a simple Library Management System.
#
# Reuse and extend your solution as you progress through the questions.
#
# By the end of this section, you'll have built another real-world application using the concepts you've learned so far.

# %% [markdown]
# ## Question 11
#
# Create a dictionary to store information about a library member.
#
# Include the following details:
#
# - Name
# - Age
# - City
# - Membership Type
#
# Print the complete dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 12
#
# Create a list called `available_books`.
#
# Add at least six book names.
#
# Add another key called `"borrowed_books"` inside the member dictionary and store a list of books currently borrowed by the member.
#
# Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 13
#
# Using the list of available books and the member's borrowed books,
#
# check whether every borrowed book exists in the library.
#
# Store the result using a new key called:
#
# ```python
# "valid_borrow"
# ```
#
# Possible values:
#
# - `"Yes"`
# - `"No"`
#
# Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 14
#
# The library allows members to borrow books only if they have a **Premium** membership.
#
# Using conditional statements,
#
# store one of the following values inside the dictionary.
#
# ```python
# "borrowing_status"
# ```
#
# Possible values:
#
# - `"Allowed"`
# - `"Not Allowed"`
#
# Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 15
#
# Create another dictionary called `book_details`.
#
# Store information for at least three books.
#
# Each book should contain:
#
# - Title
# - Author
# - Available
#
# Example structure:
#
# ```python
# {
#     "Python": {
#         ...
#     }
# }
# ```
#
# Print the dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 16
#
# Suppose the member wants to borrow one more book.
#
# Before issuing the book, check:
#
# - The book exists in `book_details`.
# - The book is available.
# - The member's borrowing status is `"Allowed"`.
#
# If all conditions are satisfied,
#
# change the book's availability to `False`.
#
# Otherwise, leave the dictionary unchanged.
#
# Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 17
#
# The library rewards active members.
#
# A member is considered **Active** if:
#
# - They have borrowed at least two books.
# - Their membership type is `"Premium"`.
#
# Store the result using the key:
#
# ```python
# "member_status"
# ```
#
# Possible values:
#
# - `"Active"`
# - `"Regular"`
#
# Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 18
#
# The library is opening a new branch.
#
# Create a list called `supported_cities`.
#
# If the member's city exists in this list,
#
# store
#
# ```python
# "Nearest Branch Available"
# ```
#
# Otherwise store
#
# ```python
# "Branch Not Available"
# ```
#
# using the key:
#
# ```python
# "branch_status"
# ```
#
# Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 19
#
# Create a dictionary called `fine_details`.
#
# Store:
#
# - Fine Amount
# - Fine Paid
#
# Determine whether the member is allowed to borrow more books.
#
# Rules:
#
# - Fine Amount is 0
# - OR
# - Fine Paid is `"Yes"`
#
# Store the result inside the member dictionary using the key:
#
# ```python
# "clearance"
# ```
#
# Possible values:
#
# - `"Approved"`
# - `"Pending"`
#
# Print the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 20
#
# Display a complete library membership summary using the information stored in your dictionaries.
#
# Include:
#
# - Member Name
# - Membership Type
# - Number of Borrowed Books
# - Member Status
# - Borrowing Status
# - Branch Status
# - Clearance Status
#
# Use the values stored in your dictionaries instead of manually typing them.

# %%
# Write your code here

# %% [markdown]
# # 03 Online Shopping System
#
# In this section, you'll build a simple Online Shopping System.
#
# Unlike the previous sections, these questions provide less guidance. You'll need to decide how to organize your data and apply the concepts you've learned so far.
#
# By the end of this section, you'll have built another small Python application from scratch.

# %% [markdown]
# ## Question 21
#
# Create a dictionary to store information about a customer.
#
# Include:
#
# - Name
# - City
# - Premium Member (Yes/No)
#
# Also create another dictionary to store information for at least three products.
#
# Each product should contain:
#
# - Price
# - Stock
#
# Print both dictionaries.

# %%
# Write your code here

# %% [markdown]
# ## Question 22
#
# Create a shopping cart using a list.
#
# Add at least three product names to the cart.
#
# Using the product dictionary you created earlier, check whether every product in the cart exists in the store.
#
# Print an appropriate message for each product.

# %%
# Write your code here

# %% [markdown]
# ## Question 23
#
# A customer wants to purchase one product.
#
# Before completing the purchase, check that:
#
# - The product exists in the store.
# - The stock is greater than 0.
#
# If both conditions are satisfied:
#
# - Reduce the stock by 1.
# - Print `"Purchase Successful"`.
#
# Otherwise print:
#
# - `"Product Not Available"`.
#
# Finally, print the updated product dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 24
#
# The store delivers only to selected cities.
#
# Create a list called `service_cities`.
#
# If the customer's city exists in this list,
#
# store one of the following inside the customer dictionary:
#
# - `"Delivery Available"`
# - `"Delivery Not Available"`
#
# Print the updated customer dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 25
#
# A customer receives a discount only if:
#
# - They are a Premium Member.
# - AND they have selected at least two products.
#
# Determine whether the customer receives a discount.
#
# Store the result using the key:
#
# ```python
# "discount_status"
# ```
#
# Possible values:
#
# - `"Eligible"`
# - `"Not Eligible"`
#
# Print the updated customer dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 26
#
# Create another dictionary called `payment`.
#
# Include:
#
# - Payment Method
# - Payment Status
#
# Determine whether the order can be processed.
#
# The order can be processed only if:
#
# - Payment Status is `"Successful"`.
# - Delivery is available.
#
# Store the result inside the customer dictionary using the key:
#
# ```python
# "order_status"
# ```
#
# Possible values:
#
# - `"Confirmed"`
# - `"Pending"`
#
# Print the updated customer dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 27
#
# The store wants to reward loyal customers.
#
# A customer becomes a **Gold Member** only if:
#
# - They are already a Premium Member.
# - Their order has been confirmed.
#
# Store the result using the key:
#
# ```python
# "membership_level"
# ```
#
# Possible values:
#
# - `"Gold"`
# - `"Premium"`
# - `"Regular"`
#
# Print the updated customer dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 28
#
# The store keeps supplier information for every product.
#
# Create a nested dictionary called `suppliers`.
#
# For each product, store:
#
# - Supplier Name
# - City
#
# Add this information to your existing product dictionary.
#
# Print the updated product dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Question 29
#
# The store wants to prepare an order summary.
#
# Display the following information using the values stored in your dictionaries.
#
# - Customer Name
# - Number of Products in Cart
# - Premium Member Status
# - Discount Status
# - Delivery Status
# - Order Status
# - Membership Level
#
# Do not manually type any values.

# %%
# Write your code here

# %% [markdown]
# ## Question 30
#
# Your Online Shopping System is now complete.
#
# Display a complete summary that includes:
#
# ### Customer Information
#
# - Name
# - City
# - Membership Level
#
# ### Shopping Information
#
# - Products in Cart
# - Discount Status
# - Order Status
#
# ### Product Information
#
# For every product, display:
#
# - Product Name
# - Price
# - Stock
# - Supplier Name
#
# Use only the information stored in your dictionaries and lists.

# %%
# Write your code here

# %% [markdown]
# # Mini Challenge : Event Registration System
#
# You are developing an Event Registration System.
#
# Create the necessary variables, lists, and dictionaries to store information about:
#
# - An event
# - Participants
# - Available seats
# - Registration status
#
# Your program should perform the following tasks.
#
# 1. Store event information.
# 2. Store participant information.
# 3. Check whether the participant is already registered.
# 4. Check whether seats are available.
# 5. Determine whether registration is successful.
# 6. Store the registration result.
# 7. Display a complete registration summary.
#
# Use everything you've learned so far:
#
# - Variables
# - Lists
# - Dictionaries
# - Comparison Operators
# - Membership Operators
# - Logical Operators
# - Conditional Statements

# %%
# Write your solution here

# %% [markdown]
# # Final Project Challenge
#
# Congratulations!
#
# You've completed the Python Mastery Exercises.
#
# Now it's time to build your first complete Python application.
#
# Imagine that you have received the following project from a client.
#
# Your task is to understand the requirements, design the data structures, and build the application using everything you've learned so far.
#
# There is no single correct solution.
#
# However, your project **must satisfy all of the client's requirements.**

# %% [markdown]
# ## Client Requirements
#
# A hotel wants a simple booking management system.
#
# The program should be able to:
#
# 1. Store hotel information.
# 2. Store customer details.
# 3. Store available room types.
# 4. Allow a customer to book a room.
# 5. Check whether the selected room exists.
# 6. Check whether the room is available.
# 7. Update room availability after booking.
# 8. Store the booking status.
# 9. Display a booking summary.
#
# Use the concepts you've learned so far.
#
# Your solution must include:
#
# ✔ Variables
#
# ✔ Lists
#
# ✔ Dictionaries
#
# ✔ Comparison Operators
#
# ✔ Membership Operators
#
# ✔ Logical Operators
#
# ✔ Conditional Statements
#
# You are free to decide:
#
# - Variable names
# - Dictionary structure
# - List structure
# - Conditions
# - Output format
#
# Build the program as if you were developing it for a real client.
