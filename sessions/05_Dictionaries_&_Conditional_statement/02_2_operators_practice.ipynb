# %% [markdown]
# # Predict the Output
#
# Before writing your own programs, let's practice reading comparison expressions.
#
# For each question:
#
# 1. Predict the output.
# 2. Write your answer.
# 3. Run the code and compare it with your prediction.
#
# Remember, every comparison returns either **True** or **False**.

# %% [markdown]
# ## Problem 1
#
# Predict the output before running the code.

# %%
age = 18

age >= 18

# %% [markdown]
# Write your answer here before running the code.
#
# ```__________________________________________________```

# %% [markdown]
# ## Problem 2
#
# Predict the output.

# %%
salary = 45000

salary > 50000

# %% [markdown]
# Write your answer here before running the code.
#
# ```__________________________________________________```

# %% [markdown]
# ## Problem 3
#
# Predict the output.

# %%
city = "Mumbai"

city == "Pune"

# %% [markdown]
# Write your answer here before running the code.
#
# ```__________________________________________________```

# %% [markdown]
# ## Problem 4
#
# Predict the output.

# %%
students = ["Rohan", "Ajay", "Mohan"]

"Ajay" in students

# %% [markdown]
# Write your answer here before running the code.
#
# ```__________________________________________________```

# %% [markdown]
# ## Problem 5
#
# Predict the output.

# %%
maths = 85
science = 72

(maths > 80) and (science > 80)

# %% [markdown]
# Write your answer here before running the code.
#
# ```__________________________________________________```

# %% [markdown]
# These examples introduced comparison, membership, and logical operators individually.
#
# In real programs, you'll often use them together inside conditional statements.
#
# Now it's your turn to start writing your own programs.

# %% [markdown]
# # Practice Questions
#
# Try solving these questions without referring back to the examples.
#
# If you get stuck, revisit the relevant section and try again.
#
# Remember, the goal is not just to write code but to understand **why** you're writing it.

# %% [markdown]
# ## Problem 1
#
# Create two variables:
#
# - `num1`
# - `num2`
#
# Print the result of the following comparisons:
#
# - Equal to (`==`)
# - Not Equal to (`!=`)
# - Greater Than (`>`)
# - Less Than (`<`)

# %%
# Write your code here

# %% [markdown]
# ## Problem 2
#
# Create a variable called `age`.
#
# Check and print the result of the following comparisons:
#
# - Is the age greater than or equal to 18?
# - Is the age less than 60?
#
# Observe whether each comparison returns `True` or `False`.

# %%
# Write your code here

# %% [markdown]
# ## Problem 3
#
# Create two string variables:
#
# - `city1`
# - `city2`
#
# Compare them using:
#
# - `==`
# - `!=`
#
# Print both results.

# %%
# Write your code here

# %% [markdown]
# ## Problem 4
#
# You are given the following list.
#
# ```python
# students = [
#     "Rohan",
#     "Mohan",
#     "Ajay",
#     "Vijay"
# ]
# ```
#
# Check whether the following students are present in the list.
#
# - `"Ajay"`
# - `"Mayank"`
#
# Print the result of each check.

# %%
# Write your code here

# %% [markdown]
# ## Problem 5
#
# Create a dictionary to store information about a laptop.
#
# Include the following keys:
#
# - Brand
# - RAM
# - Storage
#
# Check whether the key `"RAM"` exists in the dictionary.
#
# Then check whether the key `"Price"` exists.
#
# Print both results.
#
# *(Hint: Use the `in` operator.)*

# %%
# Write your code here

# %% [markdown]
# ## Problem 6
#
# A student is eligible for a scholarship only if:
#
# - Maths marks are greater than 80.
# - Science marks are greater than 80.
#
# Create variables for both subjects.
#
# Use the appropriate logical operator to determine whether the student is eligible.
#
# Print the result.

# %%
# Write your code here

# %% [markdown]
# ## Problem 7
#
# A movie ticket is free if the person is:
#
# - Under 5 years old
# - OR
# - Above 60 years old
#
# Create a variable called `age`.
#
# Write a program that prints:
#
# - `"Free Ticket"`
# - `"Regular Ticket"`
#
# using an `if` statement.

# %%
# Write your code here

# %% [markdown]
# ## Problem 8
#
# A user can log in only if:
#
# - The username is `"admin"`
# - AND
# - The password is `"python123"`
#
# Create variables for both values.
#
# Print:
#
# - `"Login Successful"`
# - `"Invalid Credentials"`
#
# using conditional statements.

# %%
# Write your code here

# %% [markdown]
# ## Problem 9
#
# You are given the following list.
#
# ```python
# students = [
#     "Rohan",
#     "Mohan",
#     "Ajay",
#     "Vijay"
# ]
# ```
#
# Also create a variable called `marks`.
#
# A student is eligible for a coding competition only if:
#
# - The student is present in the `students` list.
# - The student has scored **75 or more** marks.
#
# Create another variable called `student_name`.
#
# Using conditional statements, print:
#
# - `"Eligible for Competition"`
# - `"Not Eligible"`

# %%
# Write your code here

# %% [markdown]
# ## Problem 10
#
# You are given the following dictionary.
#
# ```python
# employee = {
#     "name": "John",
#     "department": "HR",
#     "salary": 60000
# }
# ```
#
# An employee receives a bonus only if:
#
# - The key `"salary"` exists in the dictionary.
# - The salary is **₹50,000 or more**.
#
# Using conditional statements:
#
# - Print `"Bonus Approved"` if the employee is eligible.
# - Otherwise print `"Bonus Not Approved"`.

# %%
# Write your code here

# %% [markdown]
# # Mini Challenge : College Admission Eligibility System
#
# You are building a simple college admission system.
#
# Create the following dictionary.
#
# ```python
# student = {
#     "name": "Rohan",
#     "maths": 88,
#     "science": 91,
#     "city": "Mumbai"
# }
# ```
#
# Perform the following tasks.
#
# 1. Check whether the student is from `"Mumbai"`.
# 2. Check whether the student scored more than **80** in both Maths and Science.
# 3. If both conditions are satisfied, print:
#
# ```text
# Admission Approved
# ```
#
# Otherwise print:
#
# ```text
# Admission Rejected
# ```
#
# 4. Add a new key called `"status"` to the dictionary.
#
# Store either:
#
# - `"Approved"`
# - `"Rejected"`
#
# 5. Print the final dictionary.

# %%
# Write your solution below
