# %% [markdown]
# # Practice Questions
#
# Try solving these questions without referring back to the examples.
#
# If you get stuck, revisit the relevant section and try again.
#
# Remember, the goal is not just to write code but to understand **why** you're writing it.

# %% [markdown]
# ## Problem 1
#
# Predict the output before running the code.

# %%
marks = 75

if marks >= 40:
    print("Passed")
else:
    print("Failed")

# %% [markdown]
# ### Write your answer here before running the code.
# double click here to write your answer and be honest with your self.
# ```text
# ____________________________________________________________________
# ```

# %% [markdown]
# ## Problem 2
#
# Predict the output.

# %%
marks = 30

if marks >= 40:
    print("Passed")
else:
    print("Failed")

# %% [markdown]
# ### Write your answer here before running the code.
# double click here to write your answer and be honest with your self.
# ```text
# ____________________________________________________________________
# ```

# %% [markdown]
# ## Problem 3
#
# Predict the output.

# %%
temperature = 18

if temperature < 10:
    print("Very Cold")
elif temperature < 20:
    print("Cold")
else:
    print("Hot")

# %% [markdown]
# ### Write your answer here before running the code.
# double click here to write your answer and be honest with your self.
# ```text
# ____________________________________________________________________
# ```

# %% [markdown]
# ## Problem 4
#
# Predict the output.

# %%
age = 22

if age < 18:
    print("Minor")
elif age < 60:
    print("Adult")
else:
    print("Senior Citizen")

# %% [markdown]
# ### Write your answer here before running the code.
# double click here to write your answer and be honest with your self.
# ```text
# ____________________________________________________________________
# ```

# %% [markdown]
# ## Problem 5
#
# Predict the output.

# %%
number = 100

if number < 50:
    print("Small")
elif number < 100:
    print("Medium")
else:
    print("Large")
# Out:
# Large

# %% [markdown]
# ### Write your answer here before running the code.
# double click here to write your answer and be honest with your self.
# ```text
# ____________________________________________________________________
# ```

# %% [markdown]
# ## Problem 6
#
# Predict the output before running the code.
#
# Pay close attention to how the value of the variable changes.

# %%
balance = 5000

if balance >= 3000:
    balance = balance - 1500

print(balance)
# Out:
# 3500

# %% [markdown]
# ### Write your answer here before running the code.
# double click here to write your answer and be honest with your self.
# ```text
# ____________________________________________________________________
# ```

# %% [markdown]
# ## Problem 7
#
# Create a program to determine whether a person is eligible to vote.
#
# Rules:
#
# - Age 18 or above → `"Eligible to Vote"`
# - Otherwise → `"Not Eligible"`
#
# Print the result.

# %%
# Write your code here

# %% [markdown]
# ## Problem 8
#
# Create a login system.
#
# Rules:
#
# - If the password is `"python123"` → `"Login Successful"`
# - Otherwise → `"Incorrect Password"`
#
# Print the appropriate message.

# %%
# Write your code here

# %% [markdown]
# ## Problem 9
#
# A bank allows withdrawals only if the account balance is at least ₹1000.
#
# Rules:
#
# - ₹1000 or more → `"Withdrawal Allowed"`
# - Otherwise → `"Insufficient Balance"`
#
# Print the result.

# %%
# Write your code here

# %% [markdown]
# ## Problem 10
#
# Create a grading system.
#
# Rules:
#
# - Below 40 → Failed
# - 40–59 → Grade D
# - 60–69 → Grade C
# - 70–79 → Grade B
# - 80–89 → Grade A
# - 90 and above → Grade A+
#
# Print the student's grade.

# %%
# Write your code here

# %% [markdown]
# ## Problem 11
#
# Create a traffic signal program.
#
# Rules:
#
# - Red → Stop
# - Yellow → Slow Down
# - Green → Go
# - Otherwise → Invalid Signal
#
# Print the correct action.

# %%
# Write your code here

# %% [markdown]
# ## Problem 12
#
# Create a ticket pricing system.
#
# Rules:
#
# - Under 5 → Free
# - 5–17 → ₹100
# - 18–59 → ₹200
# - 60+ → ₹120
#
# Print the ticket price.

# %%
# Write your code here

# %% [markdown]
# ## Problem 13
#
# A school gives **5 bonus marks** to students who score below 40.
#
# Perform the following:
#
# 1. Create a variable called `marks`.
# 2. If the marks are below 40, add 5 bonus marks.
# 3. Print the updated marks.
# 4. Print whether the student has **Passed** or **Failed** after the bonus marks are added.

# %%
# Write your code here

# %% [markdown]
# ## Problem 14
#
# You are given the following list.
#
# ```python
# marks = [78, 35, 92, 41, 29]
# ```
#
# Without changing the list:
#
# For each student's marks:
#
# - If marks are 40 or above, print `"Passed"`.
# - Otherwise, print `"Failed"`.
#
# *(Hint: Access each value using its index.)*

# %%
# Write your code here

# %% [markdown]
# ## Problem 15
#
# You are given the following dictionary.
#
# ```python
# student = {
#     "name": "Rohan",
#     "marks": 82
# }
# ```
#
# Perform the following:
#
# - If the marks are 40 or above, add a new key called `"result"` with the value `"Passed"`.
# - Otherwise, store `"Failed"`.
#
# Finally, print the complete dictionary.

# %%
# Write your code here

# %% [markdown]
# # Mini Challenge : Student Report Card System
#
# You are developing a simple report card system for a school.
#
# Create the following dictionary.
#
# ```python
# student = {
#     "name": "Rohan",
#     "marks": [78, 65, 92]
# }
# ```
#
# Perform the following tasks.
#
# 1. Calculate the **total marks**.
# 2. Calculate the **average marks**.
# 3. Store both values inside the dictionary as new keys called `"total"` and `"average"`.
# 4. Assign a grade using the following rules:
#
# - Below 40 → Failed
# - 40–59 → Grade D
# - 60–69 → Grade C
# - 70–79 → Grade B
# - 80–89 → Grade A
# - 90 and above → Grade A+
#
# 5. Store the grade inside the dictionary using the key `"grade"`.
# 6. Print the final dictionary.

# %%
# Write your code here
