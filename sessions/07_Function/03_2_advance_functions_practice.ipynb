# %% [markdown]
# # Predict the Output
#
# Before running each program, try to predict the output.
#
# If the code produces an error, explain why.

# %% [markdown]
# ## Problem 1
#
# Predict the output.

# %%
def greet(name, city="Pune"):
    print(name, "-", city)

greet("Rohan")
greet("Ajay", "Mumbai")

# %%
# Write your answer here before running the code.

# %% [markdown]
# ## Problem 2
#
# Predict the output.

# %%
def calculate(maths, science, english):

    total = maths + science + english

    percentage = total / 300 * 100

    return total, round(percentage, 2)

result = calculate(80, 70, 90)

print(result)

# %%
# Write your answer here before running the code.

# %% [markdown]
# ## Problem 3
#
# Predict the output.

# %%
def total_marks(*marks):

    total = 0

    for mark in marks:
        total += mark

    return total

print(total_marks(80, 75))
print(total_marks(80, 75, 90, 60))

# %%
# Write your answer here before running the code.

# %% [markdown]
# ## Problem 4
#
# Predict the output.

# %%
def student_details(name, **subjects):

    print(name)

    for subject, mark in subjects.items():
        print(subject, mark)

student_details(
    "Rohan",
    Maths=82,
    Science=91
)

# %%
# Write your answer here before running the code.

# %% [markdown]
# ## Problem 5
#
# Predict the output.

# %%
square = lambda number: number ** 2

print(square(4))
print(square(7))

# %%
# Write your answer here before running the code.

# %% [markdown]
# # Practice Questions
#
# Use what you've learned in this notebook to solve the following problems.
#
# Try to solve each problem without referring back to the examples.
#
# Remember, the goal is not just to make the code work, but to write reusable and flexible functions.

# %% [markdown]
# ## Problem 1
#
# Create a function named `student_info()` that accepts:
#
# - Name
# - Age
#
# Set the default city to **"Pune"**.
#
# Call the function:
#
# - Once without providing the city.
# - Once by providing a different city.

# %%
# Write your code here

# %% [markdown]
# ## Problem 2
#
# Create a function named `calculate_result()`.
#
# The function should accept marks for three subjects and return:
#
# - Total Marks
# - Percentage
#
# Store both returned values in separate variables and display them.

# %%
# Write your code here

# %% [markdown]
# ## Problem 3
#
# Create a function named `passed_students()`.
#
# The function should receive the following dictionary and return a list containing only the students who scored **50 or more**.
#
# ```python
# student_marks = {
#     "Rohan": 83,
#     "Mohan": 91,
#     "Ajay": 48,
#     "Chandu": 74,
#     "Vijay": 35
# }
# ```

# %%
# Write your code here

# %% [markdown]
# ## Problem 4
#
# Create a function named `calculate_average()` using `*args`.
#
# The function should accept any number of marks and return the average.
#
# Test your function using:
#
# - Three marks
# - Five marks

# %%
# Write your code here

# %% [markdown]
# ## Problem 5
#
# Create a function named `student_report()`.
#
# The function should accept:
#
# - Student Name
# - Any number of subject marks using `**kwargs`
#
# Display:
#
# - Student Name
# - Every subject with its marks
# - Total Marks

# %%
# Write your code here

# %% [markdown]
# ## Problem 6
#
# Create a function named `calculate_grade()`.
#
# The function should accept any number of subject marks using `*args`.
#
# It should return:
#
# - Total Marks
# - Percentage
# - Grade
#
# Use the following grading rules:
#
# ```
# Percentage >= 90 → A
# Percentage >= 75 → B
# Percentage >= 60 → C
# Otherwise → D
# ```

# %%
# Write your code here

# %% [markdown]
# ## Problem 7
#
# Create a function named `inventory_value()`.
#
# The function should receive product details using `**kwargs`.
#
# Each keyword represents a product and its value represents the stock.
#
# Assume every product costs **₹500**.
#
# Display the inventory value of every product.
#
# Example:
#
# ```python
# inventory_value(
#     Laptop=5,
#     Mouse=20,
#     Keyboard=8
# )
# ```

# %%
# Write your code here

# %% [markdown]
# ## Problem 8
#
# Create a lambda function that converts temperatures from Celsius to Fahrenheit.
#
# Formula:
#
# ```
# F = (C × 9 / 5) + 32
# ```
#
# Use your lambda function to convert:
#
# - 25°C
# - 30°C
# - 40°C

# %%
# Write your code here

# %% [markdown]
# ## Problem 9
#
# Create a function named `student_summary()`.
#
# The function should accept:
#
# - Student Name
# - Any number of subject marks using `**kwargs`
#
# The function should return:
#
# - Total Marks
# - Percentage
# - Grade
#
# Display the returned values outside the function.

# %%
# Write your code here

# %% [markdown]
# ## Problem 10
#
# Create a reusable function named `highest_mark()`.
#
# The function should accept any number of marks using `*args`.
#
# Return:
#
# - Highest Mark
# - Lowest Mark
# - Average Mark
#
# Store the returned values in separate variables and display them.

# %%
# Write your code here

# %% [markdown]
# # Mini Challenge: Student Report Generator
#
# You have been hired to build a reusable report generator for a school.
#
# Instead of writing separate code for every student, the school wants a single function that can generate reports for any student.
#
# Create a function named `student_report()`.

# %% [markdown]
# Your function should:
#
# ### Parameters
#
# Accept:
#
# - Student Name
# - City (Default: `"Pune"`)
# - Any number of subject marks using `**kwargs`
#
# ---
#
# ### Inside the Function
#
# Your function should:
#
# 1. Display the student's name.
# 2. Display the city.
# 3. Display every subject and its marks.
# 4. Calculate the total marks.
# 5. Calculate the percentage.
# 6. Determine the grade.
#
# Use the grading rules:
#
# ```
# Percentage >= 90 → A
# Percentage >= 75 → B
# Percentage >= 60 → C
# Otherwise → D
# ```
#
# 7. Return:
#
# - Total Marks
# - Percentage
# - Grade

# %% [markdown]
# Call your function for at least **two different students**.
#
# Example:
#
# ```python
# student_report(
#     "Rohan",
#     Maths=83,
#     Science=75,
#     English=89
# )
#
# student_report(
#     "Ajay",
#     city="Mumbai",
#     Maths=60,
#     Science=71,
#     English=55,
#     History=68
# )
# ```
#
# Store the returned values in variables and display them neatly.

# %%
# Write your solution here
