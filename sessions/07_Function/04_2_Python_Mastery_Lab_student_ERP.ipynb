# %% [markdown]
# # Python Mastery Project
#
# # School ERP System

# %% [markdown]
# ## Welcome
#
# Throughout this course, you've learned Python by solving small exercises and practice problems.
#
# Now it's time to apply everything you've learned by building a real application.
#
# ABC Public School has hired you to develop a simple School ERP System to digitize its daily operations.
#
# You'll complete one task at a time until the first version of the software is ready.
#
# Let's begin.

# %% [markdown]
# ## Task 1 : Prepare Student Storage
#
# Before storing student information, the application needs a place to keep all student records.
#
# Create an empty list named `students`.

# %%
# Write your code here

# %% [markdown]
# ## Task 2 : Create Student Records
#
# Every student should follow the same structure.
#
# Create a function named `create_student()`.
#
# The function should accept:
#
# - Name
# - Roll Number
# - Age
# - Grade
#
# Return the information as a dictionary.

# %%
# Write your code here

# %% [markdown]
# ## Task 3 : Add Students
#
# The school has provided information for its first students.
#
# Using your `create_student()` function, create at least **five student records** and store them inside the `students` list.
#
# Always use your function instead of creating dictionaries manually.

# %%
# Write your code here

# %% [markdown]
# ## Task 4 : Display Student Records
#
# The school staff wants to verify that every student's information has been stored correctly.
#
# Create a function named `display_students()` that displays every student's:
#
# - Name
# - Roll Number
# - Age
# - Grade

# %%
# Write your code here

# %% [markdown]
# ## Task 5 : Search Students
#
# Searching through every record manually is becoming difficult.
#
# Create a function named `find_student()`.
#
# The function should:
#
# - Accept a roll number.
# - Search the `students` list.
# - Return the matching student dictionary.
# - Return `None` if the student doesn't exist.

# %%
# Write your code here

# %% [markdown]
# ## Task 6 : Update Student Information
#
# Student information changes throughout the academic year.
#
# Create a function named `update_student()`.
#
# The function should:
#
# - Accept a roll number.
# - Update the student's age.
# - Update the student's grade.
# - Reuse the `find_student()` function instead of searching the list again.

# %%
# Write your code here

# %% [markdown]
# ## Task 7 : Delete Student Records
#
# Students occasionally leave the school.
#
# Create a function named `delete_student()`.
#
# The function should:
#
# - Accept a roll number.
# - Remove the student from the `students` list.
# - Reuse the `find_student()` function whenever possible.

# %%
# Write your code here

# %% [markdown]
# ## Task 8 : Student Statistics
#
# The principal wants to know the total number of students currently enrolled.
#
# Create a function named `total_students()` that returns the total number of students stored in the system.

# %%
# Write your code here

# %% [markdown]
# ## Task 9 : Grade Search
#
# The principal often needs a list of students from a particular grade during meetings.
#
# Display all students belonging to a given grade.
#
# If no students are found, display an appropriate message.
#
# > **Challenge:** Reuse your existing code whenever possible instead of writing duplicate logic.

# %%
# Write your code here

# %% [markdown]
# ## Task 10 : Student Spotlight
#
# Every year, the school recognizes the oldest student currently enrolled.
#
# Display the complete information of the oldest student in the system.
#
# > **Challenge:** Solve this without sorting the list.

# %%
# Write your code here

# %% [markdown]
# ## Task 11 : Student Insights
#
# The school counselor wants a quick overview of student demographics.
#
# Calculate and display:
#
# - Total number of students
# - Average age
# - Youngest student

# %%
# Write your code here

# %% [markdown]
# ## Task 12 : Organize Student Records
#
# Before printing student records, the principal wants them arranged alphabetically.
#
# Display all students sorted by their names.
#
# > **Hint:** Try solving this without modifying the original `students` list.

# %%
# Write your code here

# %% [markdown]
# ## Task 13 : Improve Student Search
#
# Searching students only by roll number is no longer sufficient.
#
# Enhance your application so that students can also be searched by their names.
#
# If multiple students have the same name, display all matching records.

# %%
# Write your code here

# %% [markdown]
# ## Task 14 : Student Report
#
# The principal wants a summary report before approving the next phase of the project.
#
# Generate a report displaying:
#
# - Total Students
# - Oldest Student
# - Youngest Student
# - Average Age
#
# Reuse your existing code wherever possible.

# %%
# Write your code here

# %% [markdown]
# ## Task 15 : Student Module Review
#
# Before developing the next department, verify that the Student Management Module works correctly.
#
# Demonstrate the following operations:
#
# - Add a new student
# - Search for a student
# - Update student information
# - Delete a student
# - Display all students
# - Generate the student report
#
# Reuse the functions you've created throughout this project.

# %%
# Write your code here

# %% [markdown]
# ## Project Update
#
# The Student Management Module has been successfully deployed.
#
# The school librarian has now requested that the same system be expanded to manage the library.
#
# Instead of creating a separate application, you'll continue improving the existing School ERP System.

# %% [markdown]
# ## Task 16 : Prepare Library Storage
#
# The library needs a place to store information about every book.
#
# Create an empty list named `books`.

# %%
# Write your code here

# %% [markdown]
# ## Task 17 : Create Book Records
#
# Every book in the library should follow the same structure.
#
# Create a reusable solution that stores the following information for each book:
#
# - Title
# - Author
# - Book ID
# - Availability Status
#
# New books should be available by default.

# %%
# Write your code here

# %% [markdown]
# ## Task 18 : Build the Library Catalog
#
# The librarian has shared the details of the first few books.
#
# Add at least **six books** to the library using the solution you created in the previous task.

# %%
# Write your code here

# %% [markdown]
# ## Task 19 : Browse the Library
#
# The librarian wants to see all books currently stored in the system.
#
# Display each book along with its:
#
# - Title
# - Author
# - Book ID
# - Availability Status

# %%
# Write your code here

# %% [markdown]
# ## Task 20 : Find a Book
#
# Searching through every book manually is becoming difficult.
#
# Allow the librarian to search for a book using its **Book ID**.
#
# If the book exists, display its information.
#
# Otherwise, display an appropriate message.

# %%
# Write your code here

# %% [markdown]
# ## Task 21 : Issue a Book
#
# When a student borrows a book, it should no longer appear as available.
#
# Update your application so that a book can be issued using its **Book ID**.
#
# If the book is already issued, inform the librarian.

# %%
# Write your code here

# %% [markdown]
# ## Task 22 : Return a Book
#
# When a student returns a book, it should become available again.
#
# Update the availability status of the selected book.
#
# If the book is already available, display an appropriate message.

# %%
# Write your code here

# %% [markdown]
# ## Task 23 : Library Availability Report
#
# The librarian wants to quickly see which books can still be borrowed.
#
# Display only the books that are currently available.

# %%
# Write your code here

# %% [markdown]
# ## Task 24 : Borrowed Books Report
#
# At the end of each day, the librarian reviews all books that are currently issued.
#
# Display only the books that are not available.

# %%
# Write your code here

# %% [markdown]
# ## Task 25 : Library Summary
#
# Before expanding the ERP System further, the librarian wants a quick summary of the library.
#
# Display:
#
# - Total Books
# - Available Books
# - Issued Books
#
# Reuse your existing code whenever possible.

# %%
# Write your code here

# %% [markdown]
# ## Task 26 : Borrow a Book
#
# The librarian should be able to issue a book only if:
#
# - The student exists.
# - The book exists.
# - The book is currently available.
#
# Update your application to validate all three conditions before issuing a book.
#
# If the book is successfully issued:
#
# - Mark the book as unavailable.
# - Store the student's roll number in the book record.

# %%
# Write your code here

# %% [markdown]
# ## Task 27 : Return a Book
#
# When a student returns a book, the application should:
#
# - Verify that the book exists.
# - Verify that the book is currently issued.
#
# If both conditions are satisfied:
#
# - Mark the book as available.
# - Remove the student's roll number from the book record.

# %%
# Write your code here

# %% [markdown]
# ## Task 28 : View Borrowed Books
#
# The librarian wants to know which books are currently borrowed by a particular student.
#
# Display all books borrowed by a student using their roll number.
#
# If the student has not borrowed any books, display an appropriate message.

# %%
# Write your code here

# %% [markdown]
# ## Task 29 : Borrowing Limit
#
# To ensure fair access, a student can borrow a maximum of **3 books**.
#
# Update your borrowing system so that a student cannot borrow more than three books at a time.
#
# Display an appropriate message if the limit has been reached.

# %%
# Write your code here

# %% [markdown]
# ## Task 30 : Student Library Profile
#
# The librarian wants to quickly view a student's library activity.
#
# Display:
#
# - Student Name
# - Roll Number
# - Grade
# - Number of Borrowed Books
# - Titles of Borrowed Books

# %%
# Write your code here

# %% [markdown]
# ## Task 31 : Book Details
#
# Display the complete information of a book using its Book ID.
#
# If the book has been issued, also display the student's name and roll number.
#
# > **Hint:** Reuse your existing student search instead of storing duplicate information.

# %%
# Write your code here

# %% [markdown]
# ## Task 32 : Remove Student Validation
#
# The school wants to prevent accidental data loss.
#
# Update your application so that a student **cannot be removed** if they currently have borrowed books.
#
# Display an appropriate message explaining why the operation cannot be completed.

# %%
# Write your code here

# %% [markdown]
# ## Task 33 : Remove Book Validation
#
# Books that are currently issued should not be removed from the library.
#
# Update your application to prevent deleting an issued book.
#
# Only available books can be removed.

# %%
# Write your code here

# %% [markdown]
# ## Task 34 : Library Dashboard
#
# Generate a summary displaying:
#
# - Total Students
# - Total Books
# - Available Books
# - Issued Books
# - Students Currently Borrowing Books
#
# Reuse your existing functions wherever possible.

# %%
# Write your code here

# %% [markdown]
# ## Task 35 : Client Acceptance Test
#
# Today is the final day of development.
#
# The principal wants to verify that the School ERP System works correctly before it is deployed.
#
# Using the application you've built, demonstrate a complete day at the school by performing realistic operations such as:
#
# - Admitting new students.
# - Adding new books to the library.
# - Borrowing and returning books.
# - Updating student information when required.
# - Handling invalid operations gracefully.
# - Displaying reports whenever requested.
#
# Feel free to choose your own sequence of operations.
#
# Your goal is to convince the client that the application is ready for use.

# %%
# Demonstrate your complete application here

# %% [markdown]
# # Congratulations!
#
# You have successfully completed Version 1 of the **School ERP System**.
#
# Throughout this project, you've combined everything you've learned so far to build a real-world application.
#
# ## Concepts Practiced
#
# - Variables
# - Data Types
# - Operators
# - Conditional Statements
# - Lists
# - Dictionaries
# - Loops
# - List Comprehensions
# - Functions
# - Advanced Functions
#
# More importantly, you've learned how to analyze requirements, divide large problems into smaller tasks, and build software step by step.
#
# In the upcoming sections of this course, you'll continue improving this project using:
#
# - Exception Handling
# - File Handling
# - Object-Oriented Programming (OOP)
#
# The School ERP System will continue to evolve as your Python skills grow.
