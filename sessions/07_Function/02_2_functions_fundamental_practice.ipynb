# %% [markdown]
# # Practice Questions
#
# Try solving these questions without referring back to the examples.
#
# Remember, the goal is not only to make the code work but also to understand **when** a function should be used.

# %% [markdown]
# ## Problem 1
#
# Predict the output before running the code.
#
# Then explain why.

# %%
def hello():
    print("Hello")

hello()
hello()

# write your code as comment before running it

# %% [markdown]
# ## Problem 2
#
# Predict the output before running the code.

# %%
def greet(name):
    print("Welcome", name)

greet("Rohan")
greet("Ajay")

# write your code as comment before running it

# %% [markdown]
# ## Problem 3
#
# Predict the output before running the code.

# %%
def multiply(a, b):
    print(a * b)

result = multiply(5, 4)

print(result)

# write your code as comment before running it

# %% [markdown]
# ## Problem 4
#
# Predict the output before running the code.

# %%
def multiply(a, b):
    return a * b

print(multiply(3, 6))

# write your code as comment before running it

# %% [markdown]
# ## Problem 5
#
# Predict the output before running the code.

# %%
def add(a, b):
    return a + b

result = add(10, 20)

print(result + 15)

# write your code as comment before running it

# %% [markdown]
# ## Problem 6
#
# Create a function called `welcome()` that prints:
#
# ```
# Welcome to Python Programming
# ```
#
# Call the function three times.

# %%
# Write your code here

# %% [markdown]
# ## Problem 7
#
# Create a function called `introduce()` that accepts a student's name as a parameter.
#
# Print:
#
# ```
# Hello <student_name>
# ```
#
# Call the function for three different students.

# %%
# Write your code here

# %% [markdown]
# ## Problem 8
#
# Create a function called `find_square()`.
#
# It should receive a number and print its square.
#
# Call it using five different numbers.

# %%
# Write your code here

# %% [markdown]
# ## Problem 9
#
# Create a function called `calculate_total()`.
#
# It should receive a list of marks and print the total marks.
#
# Test your function using at least two different students.

# %%
# Write your code here

# %% [markdown]
# ## Problem 10
#
# Create a function called `student_result()`.
#
# It receives the total marks.
#
# Rules:
#
# - 120 or above → Pass
# - Otherwise → Fail
#
# Print the result.

# %%
# Write your code here

# %% [markdown]
# ## Problem 11
#
# Create a function called `calculate_average()`.
#
# It receives a list of marks.
#
# Return the average instead of printing it.
#
# Store the returned value in a variable and display it.

# %%
# Write your code here

# %% [markdown]
# ## Problem 12
#
# Create a function called `find_highest()`.
#
# It should receive a list of numbers.
#
# Return the highest value from the list.
#
# Do not manually type any element.

# %%
# Write your code here

# %% [markdown]
# ## Problem 13
#
# Given:
#
# ```python
# student_marks = {
#     "Rohan": [83, 75, 89],
#     "Ajay": [45, 52, 48],
#     "Mohan": [90, 92, 88]
# }
# ```
#
# Create a function called `total_marks()`.
#
# The function should receive one student's marks list and return the total marks.
#
# Use the same function to calculate the total marks of every student.

# %%
# Write your code here

# %% [markdown]
# ## Problem 14
#
# Create a function called `grade()`.
#
# The function receives a percentage and returns:
#
# - A
# - B
# - C
# - D
#
# using the grading system you learned previously.
#
# Use the returned grade to print the final result.

# %%
# Write your code here

# %% [markdown]
# ## Problem 15
#
# Create a reusable function called `student_report()`.
#
# The function receives:
#
# - Student Name
# - Marks List
#
# The function should:
#
# - Calculate the total marks
# - Calculate the average
# - Determine Pass or Fail
# - Display a formatted report
#
# Call the function for at least three different students.

# %%
# Write your code here

# %% [markdown]
# # Mini Challenge: Student Report Generator
#
# You are building a reusable report generator for a school.
#
# Create the following dictionary.
#
# ```python
# students = {
#     "Rohan": [83, 75, 89],
#     "Mohan": [90, 92, 88],
#     "Ajay": [45, 52, 48],
#     "Chandu": [65, 78, 74]
# }
# ```
#
# Create reusable functions to complete the following tasks.
#
# 1. Create a function to calculate the total marks.
# 2. Create a function to calculate the average marks.
# 3. Create a function to determine whether the student passed or failed.
# 4. Display the report for every student.
#
# The output should look similar to:
#
# ```
# Rohan
# Total : 247
# Average : 82.33
# Result : Pass
#
# ------------------------
#
# Mohan
# Total : ...
# Average : ...
# Result : ...
# ```
#
# **Try to avoid writing the same logic more than once.**

# %%
# Write your code here
