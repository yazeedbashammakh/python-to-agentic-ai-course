# %% [markdown]
# # Practice 1: Create Strings
#
# Create variables:
#
# - name
# - city
# - profession
#
# Print each variable.

# %%
# Write your code here

# %% [markdown]
# # Practice 2: Length of a String
#
# Create a variable called `course_name`.
#
# Find its length using `len()`.

# %%
# Write your code here

# %% [markdown]
# # Practice 3: Indexing
#
# Given:
#
# ```python
# text = "Artificial Intelligence"
# ```
#
# Find:
#
# - First character
# - Fifth character
# - Last character

# %%
# Write your code here

# %% [markdown]
# # Practice 4: Slicing
#
# Using:
#
# ```python
# text = "Machine Learning"
# ```
#
# Extract:
#
# - "Machine"
# - "Learning"

# %%
# Write your code here

# %% [markdown]
# # Practice 5: String Methods
#
# Convert the following string:
#
# ```python
# message = "python is awesome"
# ```
#
# To:
#
# - Uppercase
# - Title Case

# %%
# Write your code here

# %% [markdown]
# # Practice 6: String Formatting
#
# Create variables:
#
# ```python
# name
# age
# city
# ```
#
# Display:
#
# ```text
# Hello, my name is <name>.
# I am <age> years old and live in <city>.
# ```

# %%
# Write your code here

# %% [markdown]
# # Challenge 1
#
# Create a variable:
#
# ```python
# word = "Python"
# ```
#
# Without typing the word again:
#
# Output:
#
# ```text
# PythonPythonPython
# ```

# %%
# Write your code here

# %% [markdown]
# # Challenge 2
#
# Create:
#
# ```python
# first_name = "John"
# last_name = "Doe"
# ```
#
# Output:
#
# ```text
# Doe, John
# ```
#
# using string operations.

# %%
# Write your code here
