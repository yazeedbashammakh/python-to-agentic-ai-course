# %% [markdown]
# Variables:

# %%
x = 10
y = 2*x+20
print(y)
# Out:
# 40

# %% [markdown]
# Learning Management System (LMS):
# - Students, Teacher, exam, attendance. courses, enrollments.
#
# - Student Data (info):
#   - Class: 5                            --> Integer (Number)
#   - Roll_no: 51                         --> Integer (Number)
#   - First Name: Ramesh                  --> String (Text)
#   - Last Name: Sai                      --> String
#   - Age: 10                             --> Integer
#   - attendance_percentage: 85.6         --> Float
#   - is_eligible_for_scholarship: True.  --> Boolean
#   - hostel_room_no: None                --> Nonetype

# %%
maths = 85
percentage = 100*maths/100
print(percentage)
# Out:
# 85.0

# %%
# To check data type of a variable
print(type(percentage))
# Out:
# <class 'float'>

# %%
# Write strings in quotes ", ', """, '''

f_name = "Ramesh"
l_name = 'Sai'

# %%
2+3
# Out:
# 5

# %%
# Concatenation
'a' + 'b'
# Out:
# 'ab'

# %%
full_name = f_name + " " + l_name
print(full_name)
# Out:
# Ramesh Sai

# %%
len(full_name)
# Out:
# 10

# %%
full_name.upper()
# Out:
# 'RAMESH SAI'

# %%
full_name.lower()
# Out:
# 'ramesh sai'

# %%
full_name.title()
# Out:
# 'Ramesh Sai'

# %%
# Whitespace cleanup
new_student = "   Arnab pathan   "
new_student = new_student.strip()

# %%
new_student = new_student.replace("pathan", "goswami")

# %%
new_student
# Out:
# 'Arnab goswami'

# %%
# String Formating
name = 'suresh'

print("Hi " + name + "!! Welcome to our website")
print(f"Hi {name}!! Welcome to our website")
# Out:
# Hi suresh!! Welcome to our website
# Hi suresh!! Welcome to our website

# %%
name = 'Suresh'
std = 5
roll_no = 51
attendance_percentage = 87.5


# School Leaving certificate
# name: .........
# std: .........
# roll_no:.......
# attendance_percentage: ..........
# This student has very successfully completed the school duration.

# %%
print(f"""School Leaving certificate
name: {name}
std: {std}
roll_no:{roll_no}
attendance_percentage: {attendance_percentage}
This student has very successfully completed the school duration.
""")
# Out:
# School Leaving certificate
# name: Suresh
# std: 5
# roll_no:51
# attendance_percentage: 87.5
# This student has very successfully completed the school duration.

# %%
# Sur  e   s    h
# 012  3   4    5
#     -3  -2  -1

# %%
# Substring
name[-2]
# Out:
# 's'

# %%
f_name[0] + l_name[0]
# Out:
# 'RS'

# %%
# Slicing
# string[ starting_index : end_index + 1 ]
name[0:3]
# Out:
# 'Sur'

# %%
name[-3:-1]
# Out:
# 'es'

# %%
name[:]
# Out:
# 'Suresh'

# %%
# ID Card 51, 5, Ramesh
# ID: 515Ram
id = str(roll_no) + str(std) + name[:3]
print(id)
# Out:
# 515Sur

# %%
# Typecasting (Change the data type of a variable)
# type(roll_no)
type(str(roll_no))
# Out:
# str

# %%
# int --> string.   --> str()
# string --> int.   --> int()
# string --> float  --> float()

roll_no1 = '51'
int(roll_no1)
# Out:
# 51

# %%
# float --> string
float('56.6')
# Out:
# 56.6

# %%
'56.6' + '51'
# Out:
# '56.651'

# %%
float('56.6') + int('51')
# Out:
# 107.6
