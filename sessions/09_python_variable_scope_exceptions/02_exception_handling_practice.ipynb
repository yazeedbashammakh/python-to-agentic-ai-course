# %% [markdown]
# # Practice Questions
#
# Use everything you've learned in this notebook to solve the following problems.
#
# Try solving each problem before looking at the solution.
#
# Remember, the goal is not only to prevent programs from crashing, but also to build applications that handle unexpected situations gracefully.

# %% [markdown]
# ## Problem 1
#
# Create a program that asks the user to enter their age.
#
# Requirements:
#
# - Handle invalid input using exception handling.
# - If no exception occurs, display:
#
# ```
# Age Recorded Successfully.
# ```
#
# - Always display:
#
# ```
# Thank you.
# ```

# %%
# Write your code here

# %% [markdown]
# ## Problem 2
#
# Create a calculator that asks the user to enter two numbers.
#
# Requirements:
#
# - Handle invalid numeric input.
# - Handle division by zero.
# - Display the result only if no exception occurs.
# - Always display:
#
# ```
# Program Finished.
# ```

# %%
# Write your code here

# %% [markdown]
# ## Problem 3
#
# Create a program that asks the user to enter student marks.
#
# Requirements:
#
# - Marks must be between **0 and 100**.
# - Use `raise` if the marks are invalid.
# - Display the original exception message.

# %%
# Write your code here

# %% [markdown]
# ## Problem 4
#
# Create a program that asks the user for a withdrawal amount.
#
# Requirements:
#
# - Handle invalid input.
# - Withdrawal amount cannot be negative.
# - Use `raise`.
# - Display:
#
# ```
# Transaction Successful.
# ```
#
# only if no exception occurs.
#
# Always display:
#
# ```
# Visit Again.
# ```

# %%
# Write your code here

# %% [markdown]
# ## Problem 5
#
# Use the following dictionary.
#
# ```python
# students = {
#     "Rohan": 82,
#     "Ajay": 91,
#     "Vijay": 75
# }
# ```
#
# Ask the user to enter a student name.
#
# Requirements:
#
# - Display the student's marks.
# - Handle the situation where the student does not exist.
# - Display an appropriate error message.

# %%
# Write your code here

# %% [markdown]
# ## Problem 6
#
# Create a program that asks the user to enter a product price.
#
# Requirements:
#
# - Handle invalid input.
# - Price cannot be negative.
# - Use `raise`.
# - Display the original exception message.

# %%
# Write your code here

# %% [markdown]
# ## Problem 7
#
# Create a program that asks the user to enter an employee's salary.
#
# Requirements:
#
# - Salary must be greater than zero.
# - Use `raise`.
# - Display:
#
# ```
# Salary Saved Successfully.
# ```
#
# only if no exception occurs.
#
# Always display:
#
# ```
# Operation Completed.
# ```

# %%
# Write your code here

# %% [markdown]
# ## Problem 8
#
# Create a program that asks the user for the number of overdue days.
#
# Requirements:
#
# - Handle invalid input.
# - Days cannot be negative.
# - Calculate the fine using:
#
# ```
# Fine = Days × ₹20
# ```
#
# - Display the fine only if no exception occurs.

# %%
# Write your code here

# %% [markdown]
# ## Problem 9
#
# Create a program that asks the user to enter marks.
#
# Requirements:
#
# - Handle invalid input.
# - Marks must be between **0 and 100**.
# - Use `raise` if the marks are invalid.
# - Calculate the grade using:
#
# ```
# 90+      → A
# 75–89    → B
# 60–74    → C
# Below 60 → D
# ```
#
# Display the grade only if no exception occurs.

# %%
# Write your code here

# %% [markdown]
# ## Problem 10
#
# Create an ATM withdrawal program.
#
# Requirements:
#
# - Ask the user to enter the withdrawal amount.
# - Handle invalid input.
# - Withdrawal amount cannot be negative.
# - Display:
#
# ```
# Processing Transaction...
# ```
#
# inside the `try` block.
#
# Display:
#
# ```
# Transaction Successful.
# ```
#
# inside the `else` block.
#
# Always display:
#
# ```
# Thank you for using our ATM.
# ```
#
# inside the `finally` block.

# %%
# Write your code here

# %% [markdown]
# # Mini Challenge: Student Registration System
#
# Your client wants a crash-proof Student Registration System.
#
# Create a program that asks the user to enter:
#
# - Student Name
# - Age
# - Marks
#
# Requirements:
#
# - Handle invalid numeric input.
# - Age must be greater than zero.
# - Marks must be between **0 and 100**.
# - Use `raise` whenever one of the application's rules is violated.
# - Display:
#
# ```
# Student Registered Successfully.
# ```
#
# only if all information is valid.
#
# Always display:
#
# ```
# Returning to Main Menu...
# ```

# %%
# Write your solution here

# %% [markdown]
# # Final Challenge: Student Result Management System
#
# ## Client Requirement
#
# You have been hired to improve a Student Result Management System.
#
# The current application crashes whenever users enter invalid data. Your task is to build a reliable application that handles unexpected situations without terminating.
#
# ---
#
# ## Functional Requirements
#
# Your application should display the following menu:
#
# ```
# ===== Student Result Management System =====
#
# 1. Add Student Result
# 2. View Student Result
# 3. Exit
# ```
#
# ### Option 1 — Add Student Result
#
# Ask the user to enter:
#
# - Student Name
# - Student Marks
#
# Requirements:
#
# - Marks must be numeric.
# - Marks must be between **0 and 100**.
# - Use `raise` if the marks violate the application's rules.
# - Handle all exceptions appropriately.
# - Display:
#
# ```
# Student Result Saved Successfully.
# ```
#
# only if the operation succeeds.
#
# ---
#
# ### Option 2 — View Student Result
#
# Ask the user to enter a student name.
#
# Requirements:
#
# - Display the student's marks if the record exists.
# - Handle the situation where the student does not exist.
# - Display an appropriate error message instead of allowing the application to crash.
#
# ---
#
# ### Option 3 — Exit
#
# Display:
#
# ```
# Thank you for using the Student Result Management System.
# ```
#
# and terminate the application.
#
# ---
#
# ## Additional Requirements
#
# Your application must:
#
# - Continue running until the user selects **Exit**.
# - Handle invalid menu selections.
# - Handle invalid numeric input.
# - Prevent the application from crashing.
# - Display meaningful error messages.
# - Use `else` to display success messages.
# - Use `finally` wherever code must always execute.
