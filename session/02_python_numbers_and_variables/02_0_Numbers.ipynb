# %% [markdown]
# # Introduction to Google Colab
#
# Google Colab is a cloud-based notebook environment.
#
# Advantages:
# - No installation required
# - Runs in a browser
# - Easy to share
# - Suitable for learning and experimentation
#
# We will begin our journey using Google Colab.
#
#
# # How to create your first notebook
# - Goto Colab URL: https://colab.research.google.com/
# - Sign in to gogle if you are not signed in
# - Click (+ Create New Notebook)

# %% [markdown]
# # What is a Notebook?
#
# A notebook combines:
#
# - Explanations
# - Code
# - Outputs
#
# This allows us to learn concepts and execute code in the same document.

# %% [markdown]
# File extension: ipynb --> interactive python notebook --> Good for rapid, development, testing and experimentation.
# File scripts: .py --> Ideal for deployment, automation etc.

# %%
# print function 

print("My name is Rahul")
print("I want to become an AI Engineer")

# print("""
# Welcome to the Python & Agentic AI Course!
# Today, you are writing code.
# Soon, your code will be building autonomous AI agents.
# """)

# %%
# These are comment, Comments are ignored by the Python interpreter. They are used to explain the code and make it more readable.
print(1)
# print(2) # This line is commented out and will not be executed

# %% [markdown]
# # Numbers in Python (Integer and Float)

# %% [markdown]
# ## Integers
#
# Integers are just whole numbers, positive or negative. For example: 2 and -2 are examples of integers.
#
#
# ## Float
# Floating point numbers have a decimal point in them. Ex. 2.5, -2.3, 10.5

# %% [markdown]
# ### Basic Arithmetic

# %%
# Addition
2+1

# %%
# Subtraction
2-1

# %%
# Multiplication
2*2

# %%
# Division
3/2

# %%
# Floor Division
3//2

# %%
# Modulo / remainder
7%4

# %% [markdown]
# ### Arithmetic continued

# %%
# Powers
2**3

# %%
# Can also do roots this way
4**0.5

# %%
# Order of Operations followed in Python
2 + 10 * 10 + 3

# %%
# Can use parentheses to specify orders
(2+10) * (10+3)
